# %% [markdown]
# # The Price is Right
#
# The final step is to build a User Interface
#
# We will use more advanced aspects of Gradio - building piece by piece.

# %%
import gradio as gr
from deal_agent_framework import DealAgentFramework
from agents.deals import Opportunity, Deal

# %%
with gr.Blocks(title="The Price is Right", fill_width=True) as ui:

    with gr.Row():
        gr.Markdown('<div style="text-align: center;font-size:24px">The Price is Right - Deal Hunting Agentic AI</div>')
    with gr.Row():
        gr.Markdown('<div style="text-align: center;font-size:14px">Autonomous agent framework that finds online deals, collaborating with a proprietary fine-tuned LLM deployed on Modal, and a RAG pipeline with a frontier model and Chroma.</div>')
        

ui.launch(inbrowser=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
# Updated to change from height to max_height due to change in Gradio v5
# With much thanks to student Ed B. for raising this

with gr.Blocks(title="The Price is Right", fill_width=True) as ui:

    initial_deal = Deal(product_description="Example description", price=100.0, url="https://cnn.com")
    initial_opportunity = Opportunity(deal=initial_deal, estimate=200.0, discount=100.0)
    opportunities = gr.State([initial_opportunity])

    def get_table(opps):
        return [[opp.deal.product_description, opp.deal.price, opp.estimate, opp.discount, opp.deal.url] for opp in opps]

    with gr.Row():
        gr.Markdown('<div style="text-align: center;font-size:24px">"The Price is Right" - Deal Hunting Agentic AI</div>')
    with gr.Row():
        gr.Markdown('<div style="text-align: center;font-size:14px">Deals surfaced so far:</div>')
    with gr.Row():
        opportunities_dataframe = gr.Dataframe(
            headers=["Description", "Price", "Estimate", "Discount", "URL"],
            wrap=True,
            column_widths=[4, 1, 1, 1, 2],
            row_count=10,
            col_count=5,
            max_height=400,
        )

    ui.load(get_table, inputs=[opportunities], outputs=[opportunities_dataframe])

ui.launch(inbrowser=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7861
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7861/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
agent_framework = DealAgentFramework()
agent_framework.init_agents_as_needed()

with gr.Blocks(title="The Price is Right", fill_width=True) as ui:

    initial_deal = Deal(product_description="Example description", price=100.0, url="https://cnn.com")
    initial_opportunity = Opportunity(deal=initial_deal, estimate=200.0, discount=100.0)
    opportunities = gr.State([initial_opportunity])

    def get_table(opps):
        return [[opp.deal.product_description, opp.deal.price, opp.estimate, opp.discount, opp.deal.url] for opp in opps]

    def do_select(opportunities, selected_index: gr.SelectData):
        row = selected_index.index[0]
        opportunity = opportunities[row]
        agent_framework.planner.messenger.alert(opportunity)

    with gr.Row():
        gr.Markdown('<div style="text-align: center;font-size:24px">"The Price is Right" - Deal Hunting Agentic AI</div>')
    with gr.Row():
        gr.Markdown('<div style="text-align: center;font-size:14px">Deals surfaced so far:</div>')
    with gr.Row():
        opportunities_dataframe = gr.Dataframe(
            headers=["Description", "Price", "Estimate", "Discount", "URL"],
            wrap=True,
            column_widths=[4, 1, 1, 1, 2],
            row_count=10,
            col_count=5,
            max_height=400,
        )

    ui.load(get_table, inputs=[opportunities], outputs=[opportunities_dataframe])
    opportunities_dataframe.select(do_select, inputs=[opportunities], outputs=[])

ui.launch(inbrowser=True)
# Out:
# [2026-09-10 23:43:09 -0400] [Agents] [INFO] Anonymized telemetry enabled. See                     https://docs.trychroma.com/telemetry for more information.
# [2026-09-10 23:43:09 -0400] [Agents] [INFO] [Agent Framework] Initializing Agent Framework
# [2026-09-10 23:43:09 -0400] [Agents] [INFO] [Planning Agent] Planning Agent is initializing
# [2026-09-10 23:43:09 -0400] [Agents] [INFO] [Scanner Agent] Scanner Agent is initializing
# [2026-09-10 23:43:09 -0400] [Agents] [INFO] [Scanner Agent] Scanner Agent is ready
# [2026-09-10 23:43:09 -0400] [Agents] [INFO] [Ensemble Agent] Initializing Ensemble Agent
# [2026-09-10 23:43:09 -0400] [Agents] [INFO] [Specialist Agent] Specialist Agent is initializing - connecting to modal
# [2026-09-10 23:43:09 -0400] [Agents] [INFO] [Frontier Agent] Initializing Frontier Agent
# [2026-09-10 23:43:09 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent is setting up with OpenAI
# [2026-09-10 23:43:09 -0400] [Agents] [INFO] Use pytorch device_name: mps
# [2026-09-10 23:43:09 -0400] [Agents] [INFO] Load pretrained SentenceTransformer: sentence-transformers/all-MiniLM-L6-v2
# [2026-09-10 23:43:11 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent is ready
# [2026-09-10 23:43:11 -0400] [Agents] [INFO] [Neural Network Agent] Neural Network Agent is initializing
# [2026-09-10 23:43:11 -0400] [Agents] [INFO] Neural Network is using mps
# [2026-09-10 23:43:12 -0400] [Agents] [INFO] [Neural Network Agent] Neural Network Agent is ready and weights are loaded
# [2026-09-10 23:43:12 -0400] [Agents] [INFO] [Ensemble Agent] Ensemble Agent is ready
# [2026-09-10 23:43:12 -0400] [Agents] [INFO] [Messaging Agent] Messaging Agent is initializing
# [2026-09-10 23:43:12 -0400] [Agents] [INFO] [Messaging Agent] Messaging Agent has initialized Pushover and Claude
# [2026-09-10 23:43:12 -0400] [Agents] [INFO] [Planning Agent] Planning Agent is ready
# [2026-09-10 23:43:12 -0400] [Agents] [INFO] [Agent Framework] Agent Framework is ready
# * Running on local URL:  http://127.0.0.1:7862
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7862/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# # Time for the code
#
# And now we'll move to the price_is_right.py code

# %%
# Reset memory back to 2 deals discovered in the past

from deal_agent_framework import DealAgentFramework
DealAgentFramework.reset_memory()

# %%
import logging
root = logging.getLogger()
root.setLevel(logging.INFO)

# %% [markdown]
# # Running the final product
#
# ## Just hit shift + enter in the next cell, and let the deals flow in!!

# %%
# !uv run price_is_right.py
# Out:
# * Running on local URL:  http://127.0.0.1:7863
# * To create a public link, set `share=True` in `launch()`.
# [2026-09-11 22:30:16 -0400] [Agents] [INFO] [Agent Framework] Initializing Agent Framework
# [2026-09-11 22:30:16 -0400] [Agents] [INFO] [Agent Framework] Initializing Agent Framework
# [2026-09-11 22:30:16 -0400] [Agents] [INFO] [Planning Agent] Planning Agent is initializing
# [2026-09-11 22:30:16 -0400] [Agents] [INFO] [Planning Agent] Planning Agent is initializing
# [2026-09-11 22:30:16 -0400] [Agents] [INFO] [Scanner Agent] Scanner Agent is initializing
# [2026-09-11 22:30:16 -0400] [Agents] [INFO] [Scanner Agent] Scanner Agent is initializing
# [2026-09-11 22:30:16 -0400] [Agents] [INFO] [Scanner Agent] Scanner Agent is ready
# [2026-09-11 22:30:16 -0400] [Agents] [INFO] [Scanner Agent] Scanner Agent is ready
# [2026-09-11 22:30:16 -0400] [Agents] [INFO] [Ensemble Agent] Initializing Ensemble Agent
# [2026-09-11 22:30:16 -0400] [Agents] [INFO] [Ensemble Agent] Initializing Ensemble Agent
# [2026-09-11 22:30:16 -0400] [Agents] [INFO] [Specialist Agent] Specialist Agent is initializing - connecting to modal
# [2026-09-11 22:30:16 -0400] [Agents] [INFO] [Specialist Agent] Specialist Agent is initializing - connecting to modal
# [2026-09-11 22:30:16 -0400] [Agents] [INFO] [Frontier Agent] Initializing Frontier Agent
# [2026-09-11 22:30:16 -0400] [Agents] [INFO] [Frontier Agent] Initializing Frontier Agent
# [2026-09-11 22:30:16 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent is setting up with OpenAI
# [2026-09-11 22:30:16 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent is setting up with OpenAI
# [2026-09-11 22:30:16 -0400] [Agents] [INFO] Use pytorch device_name: mps
# [2026-09-11 22:30:16 -0400] [Agents] [INFO] Use pytorch device_name: mps
# [2026-09-11 22:30:16 -0400] [Agents] [INFO] Load pretrained SentenceTransformer: sentence-transformers/all-MiniLM-L6-v2
# [2026-09-11 22:30:16 -0400] [Agents] [INFO] Load pretrained SentenceTransformer: sentence-transformers/all-MiniLM-L6-v2
# [2026-09-11 22:30:18 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent is ready
# [2026-09-11 22:30:18 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent is ready
# [2026-09-11 22:30:18 -0400] [Agents] [INFO] [Neural Network Agent] Neural Network Agent is initializing
# [2026-09-11 22:30:18 -0400] [Agents] [INFO] [Neural Network Agent] Neural Network Agent is initializing
# [2026-09-11 22:30:18 -0400] [Agents] [INFO] Neural Network is using mps
# [2026-09-11 22:30:18 -0400] [Agents] [INFO] Neural Network is using mps
# [2026-09-11 22:30:19 -0400] [Agents] [INFO] [Neural Network Agent] Neural Network Agent is ready and weights are loaded
# [2026-09-11 22:30:19 -0400] [Agents] [INFO] [Neural Network Agent] Neural Network Agent is ready and weights are loaded
# [2026-09-11 22:30:19 -0400] [Agents] [INFO] [Ensemble Agent] Ensemble Agent is ready
# [2026-09-11 22:30:19 -0400] [Agents] [INFO] [Ensemble Agent] Ensemble Agent is ready
# [2026-09-11 22:30:19 -0400] [Agents] [INFO] [Messaging Agent] Messaging Agent is initializing
# [2026-09-11 22:30:19 -0400] [Agents] [INFO] [Messaging Agent] Messaging Agent is initializing
# [2026-09-11 22:30:19 -0400] [Agents] [INFO] [Messaging Agent] Messaging Agent has initialized Pushover and Claude
# [2026-09-11 22:30:19 -0400] [Agents] [INFO] [Messaging Agent] Messaging Agent has initialized Pushover and Claude
# [2026-09-11 22:30:19 -0400] [Agents] [INFO] [Planning Agent] Planning Agent is ready
# [2026-09-11 22:30:19 -0400] [Agents] [INFO] [Planning Agent] Planning Agent is ready
# [2026-09-11 22:30:19 -0400] [Agents] [INFO] [Agent Framework] Agent Framework is ready
# [2026-09-11 22:30:19 -0400] [Agents] [INFO] [Agent Framework] Agent Framework is ready
# [2026-09-11 22:30:19 -0400] [Agents] [INFO] Kicking off Planning Agent
# [2026-09-11 22:30:19 -0400] [Agents] [INFO] Kicking off Planning Agent
# [2026-09-11 22:30:19 -0400] [Agents] [INFO] [Planning Agent] Planning Agent is kicking off a run
# [2026-09-11 22:30:19 -0400] [Agents] [INFO] [Planning Agent] Planning Agent is kicking off a run
# [2026-09-11 22:30:19 -0400] [Agents] [INFO] [Scanner Agent] Scanner Agent is about to fetch deals from RSS feed
# [2026-09-11 22:30:19 -0400] [Agents] [INFO] [Scanner Agent] Scanner Agent is about to fetch deals from RSS feed
# [2026-09-11 22:30:35 -0400] [Agents] [INFO] [Scanner Agent] Scanner Agent received 30 deals not already scraped
# [2026-09-11 22:30:35 -0400] [Agents] [INFO] [Scanner Agent] Scanner Agent received 30 deals not already scraped
# [2026-09-11 22:30:35 -0400] [Agents] [INFO] [Scanner Agent] Scanner Agent is calling OpenAI using Structured Outputs
# [2026-09-11 22:30:35 -0400] [Agents] [INFO] [Scanner Agent] Scanner Agent is calling OpenAI using Structured Outputs
# [2026-09-11 22:30:47 -0400] [Agents] [INFO] [Scanner Agent] Scanner Agent received 5 selected deals with price>0 from OpenAI
# [2026-09-11 22:30:47 -0400] [Agents] [INFO] [Scanner Agent] Scanner Agent received 5 selected deals with price>0 from OpenAI
# [2026-09-11 22:30:47 -0400] [Agents] [INFO] [Planning Agent] Planning Agent is pricing up a potential deal
# [2026-09-11 22:30:47 -0400] [Agents] [INFO] [Planning Agent] Planning Agent is pricing up a potential deal
# [2026-09-11 22:30:47 -0400] [Agents] [INFO] [Ensemble Agent] Running Ensemble Agent - preprocessing text
# [2026-09-11 22:30:47 -0400] [Agents] [INFO] [Ensemble Agent] Running Ensemble Agent - preprocessing text
# 22:30:47 - LiteLLM:INFO: utils.py:3421 -
# LiteLLM completion() model= llama3.2; provider = ollama
# [2026-09-11 22:30:47 -0400] [Agents] [INFO]
# LiteLLM completion() model= llama3.2; provider = ollama
# [2026-09-11 22:30:47 -0400] [Agents] [INFO]
# LiteLLM completion() model= llama3.2; provider = ollama
# 22:31:02 - LiteLLM:INFO: utils.py:1302 - Wrapper: Completed Call, calling success_handler
# [2026-09-11 22:31:02 -0400] [Agents] [INFO] Wrapper: Completed Call, calling success_handler
# [2026-09-11 22:31:02 -0400] [Agents] [INFO] Wrapper: Completed Call, calling success_handler
# [2026-09-11 22:31:02 -0400] [Agents] [INFO] [Ensemble Agent] Pre-processed text using ollama/llama3.2
# [2026-09-11 22:31:02 -0400] [Agents] [INFO] [Ensemble Agent] Pre-processed text using ollama/llama3.2
# [2026-09-11 22:31:02 -0400] [Agents] [INFO] [Specialist Agent] Specialist Agent is calling remote fine-tuned model
# [2026-09-11 22:31:02 -0400] [Agents] [INFO] [Specialist Agent] Specialist Agent is calling remote fine-tuned model
# [2026-09-11 22:32:03 -0400] [Agents] [INFO] [Specialist Agent] Specialist Agent completed - predicting $60.00
# [2026-09-11 22:32:03 -0400] [Agents] [INFO] [Specialist Agent] Specialist Agent completed - predicting $60.00
# [2026-09-11 22:32:03 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent is performing a RAG search of the Chroma datastore to find 5 similar products
# [2026-09-11 22:32:03 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent is performing a RAG search of the Chroma datastore to find 5 similar products
# Batches: 100%|████████████████████████████████████| 1/1 [00:01<00:00,  1.15s/it]
# [2026-09-11 22:32:04 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent has found similar products
# [2026-09-11 22:32:04 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent has found similar products
# [2026-09-11 22:32:04 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent is about to call gpt-5.1 with context including 5 similar products
# [2026-09-11 22:32:04 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent is about to call gpt-5.1 with context including 5 similar products
# [2026-09-11 22:32:06 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent completed - predicting $39.99
# [2026-09-11 22:32:06 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent completed - predicting $39.99
# [2026-09-11 22:32:06 -0400] [Agents] [INFO] [Neural Network Agent] Neural Network Agent is starting a prediction
# [2026-09-11 22:32:06 -0400] [Agents] [INFO] [Neural Network Agent] Neural Network Agent is starting a prediction
# [2026-09-11 22:32:06 -0400] [Agents] [INFO] [Neural Network Agent] Neural Network Agent completed - predicting $55.80
# [2026-09-11 22:32:06 -0400] [Agents] [INFO] [Neural Network Agent] Neural Network Agent completed - predicting $55.80
# [2026-09-11 22:32:06 -0400] [Agents] [INFO] [Ensemble Agent] Ensemble Agent complete - returning $43.57
# [2026-09-11 22:32:06 -0400] [Agents] [INFO] [Ensemble Agent] Ensemble Agent complete - returning $43.57
# [2026-09-11 22:32:06 -0400] [Agents] [INFO] [Planning Agent] Planning Agent has processed a deal with discount $31.57
# [2026-09-11 22:32:06 -0400] [Agents] [INFO] [Planning Agent] Planning Agent has processed a deal with discount $31.57
# [2026-09-11 22:32:06 -0400] [Agents] [INFO] [Planning Agent] Planning Agent is pricing up a potential deal
# [2026-09-11 22:32:06 -0400] [Agents] [INFO] [Planning Agent] Planning Agent is pricing up a potential deal
# [2026-09-11 22:32:06 -0400] [Agents] [INFO] [Ensemble Agent] Running Ensemble Agent - preprocessing text
# [2026-09-11 22:32:06 -0400] [Agents] [INFO] [Ensemble Agent] Running Ensemble Agent - preprocessing text
# 22:32:06 - LiteLLM:INFO: utils.py:3421 -
# LiteLLM completion() model= llama3.2; provider = ollama
# [2026-09-11 22:32:06 -0400] [Agents] [INFO]
# LiteLLM completion() model= llama3.2; provider = ollama
# [2026-09-11 22:32:06 -0400] [Agents] [INFO]
# LiteLLM completion() model= llama3.2; provider = ollama
# 22:32:07 - LiteLLM:INFO: utils.py:1302 - Wrapper: Completed Call, calling success_handler
# [2026-09-11 22:32:07 -0400] [Agents] [INFO] Wrapper: Completed Call, calling success_handler
# [2026-09-11 22:32:07 -0400] [Agents] [INFO] Wrapper: Completed Call, calling success_handler
# [2026-09-11 22:32:07 -0400] [Agents] [INFO] [Ensemble Agent] Pre-processed text using ollama/llama3.2
# [2026-09-11 22:32:07 -0400] [Agents] [INFO] [Ensemble Agent] Pre-processed text using ollama/llama3.2
# [2026-09-11 22:32:07 -0400] [Agents] [INFO] [Specialist Agent] Specialist Agent is calling remote fine-tuned model
# [2026-09-11 22:32:07 -0400] [Agents] [INFO] [Specialist Agent] Specialist Agent is calling remote fine-tuned model
# [2026-09-11 22:32:08 -0400] [Agents] [INFO] [Specialist Agent] Specialist Agent completed - predicting $40.00
# [2026-09-11 22:32:08 -0400] [Agents] [INFO] [Specialist Agent] Specialist Agent completed - predicting $40.00
# [2026-09-11 22:32:08 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent is performing a RAG search of the Chroma datastore to find 5 similar products
# [2026-09-11 22:32:08 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent is performing a RAG search of the Chroma datastore to find 5 similar products
# Batches: 100%|████████████████████████████████████| 1/1 [00:00<00:00, 23.25it/s]
# [2026-09-11 22:32:08 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent has found similar products
# [2026-09-11 22:32:08 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent has found similar products
# [2026-09-11 22:32:08 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent is about to call gpt-5.1 with context including 5 similar products
# [2026-09-11 22:32:08 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent is about to call gpt-5.1 with context including 5 similar products
# [2026-09-11 22:32:09 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent completed - predicting $39.99
# [2026-09-11 22:32:09 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent completed - predicting $39.99
# [2026-09-11 22:32:09 -0400] [Agents] [INFO] [Neural Network Agent] Neural Network Agent is starting a prediction
# [2026-09-11 22:32:09 -0400] [Agents] [INFO] [Neural Network Agent] Neural Network Agent is starting a prediction
# [2026-09-11 22:32:09 -0400] [Agents] [INFO] [Neural Network Agent] Neural Network Agent completed - predicting $63.20
# [2026-09-11 22:32:09 -0400] [Agents] [INFO] [Neural Network Agent] Neural Network Agent completed - predicting $63.20
# [2026-09-11 22:32:09 -0400] [Agents] [INFO] [Ensemble Agent] Ensemble Agent complete - returning $42.31
# [2026-09-11 22:32:09 -0400] [Agents] [INFO] [Ensemble Agent] Ensemble Agent complete - returning $42.31
# [2026-09-11 22:32:09 -0400] [Agents] [INFO] [Planning Agent] Planning Agent has processed a deal with discount $16.32
# [2026-09-11 22:32:09 -0400] [Agents] [INFO] [Planning Agent] Planning Agent has processed a deal with discount $16.32
# [2026-09-11 22:32:09 -0400] [Agents] [INFO] [Planning Agent] Planning Agent is pricing up a potential deal
# [2026-09-11 22:32:09 -0400] [Agents] [INFO] [Planning Agent] Planning Agent is pricing up a potential deal
# [2026-09-11 22:32:09 -0400] [Agents] [INFO] [Ensemble Agent] Running Ensemble Agent - preprocessing text
# [2026-09-11 22:32:09 -0400] [Agents] [INFO] [Ensemble Agent] Running Ensemble Agent - preprocessing text
# 22:32:09 - LiteLLM:INFO: utils.py:3421 -
# LiteLLM completion() model= llama3.2; provider = ollama
# [2026-09-11 22:32:09 -0400] [Agents] [INFO]
# LiteLLM completion() model= llama3.2; provider = ollama
# [2026-09-11 22:32:09 -0400] [Agents] [INFO]
# LiteLLM completion() model= llama3.2; provider = ollama
# 22:32:11 - LiteLLM:INFO: utils.py:1302 - Wrapper: Completed Call, calling success_handler
# [2026-09-11 22:32:11 -0400] [Agents] [INFO] Wrapper: Completed Call, calling success_handler
# [2026-09-11 22:32:11 -0400] [Agents] [INFO] Wrapper: Completed Call, calling success_handler
# [2026-09-11 22:32:11 -0400] [Agents] [INFO] [Ensemble Agent] Pre-processed text using ollama/llama3.2
# [2026-09-11 22:32:11 -0400] [Agents] [INFO] [Ensemble Agent] Pre-processed text using ollama/llama3.2
# [2026-09-11 22:32:11 -0400] [Agents] [INFO] [Specialist Agent] Specialist Agent is calling remote fine-tuned model
# [2026-09-11 22:32:11 -0400] [Agents] [INFO] [Specialist Agent] Specialist Agent is calling remote fine-tuned model
# [2026-09-11 22:32:11 -0400] [Agents] [INFO] [Specialist Agent] Specialist Agent completed - predicting $60.00
# [2026-09-11 22:32:11 -0400] [Agents] [INFO] [Specialist Agent] Specialist Agent completed - predicting $60.00
# [2026-09-11 22:32:11 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent is performing a RAG search of the Chroma datastore to find 5 similar products
# [2026-09-11 22:32:11 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent is performing a RAG search of the Chroma datastore to find 5 similar products
# Batches: 100%|████████████████████████████████████| 1/1 [00:00<00:00,  4.49it/s]
# [2026-09-11 22:32:12 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent has found similar products
# [2026-09-11 22:32:12 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent has found similar products
# [2026-09-11 22:32:12 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent is about to call gpt-5.1 with context including 5 similar products
# [2026-09-11 22:32:12 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent is about to call gpt-5.1 with context including 5 similar products
# [2026-09-11 22:32:13 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent completed - predicting $59.99
# [2026-09-11 22:32:13 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent completed - predicting $59.99
# [2026-09-11 22:32:13 -0400] [Agents] [INFO] [Neural Network Agent] Neural Network Agent is starting a prediction
# [2026-09-11 22:32:13 -0400] [Agents] [INFO] [Neural Network Agent] Neural Network Agent is starting a prediction
# [2026-09-11 22:32:13 -0400] [Agents] [INFO] [Neural Network Agent] Neural Network Agent completed - predicting $109.44
# [2026-09-11 22:32:13 -0400] [Agents] [INFO] [Neural Network Agent] Neural Network Agent completed - predicting $109.44
# [2026-09-11 22:32:13 -0400] [Agents] [INFO] [Ensemble Agent] Ensemble Agent complete - returning $64.94
# [2026-09-11 22:32:13 -0400] [Agents] [INFO] [Ensemble Agent] Ensemble Agent complete - returning $64.94
# [2026-09-11 22:32:13 -0400] [Agents] [INFO] [Planning Agent] Planning Agent has processed a deal with discount $-5.06
# [2026-09-11 22:32:13 -0400] [Agents] [INFO] [Planning Agent] Planning Agent has processed a deal with discount $-5.06
# [2026-09-11 22:32:13 -0400] [Agents] [INFO] [Planning Agent] Planning Agent is pricing up a potential deal
# [2026-09-11 22:32:13 -0400] [Agents] [INFO] [Planning Agent] Planning Agent is pricing up a potential deal
# [2026-09-11 22:32:13 -0400] [Agents] [INFO] [Ensemble Agent] Running Ensemble Agent - preprocessing text
# [2026-09-11 22:32:13 -0400] [Agents] [INFO] [Ensemble Agent] Running Ensemble Agent - preprocessing text
# 22:32:13 - LiteLLM:INFO: utils.py:3421 -
# LiteLLM completion() model= llama3.2; provider = ollama
# [2026-09-11 22:32:13 -0400] [Agents] [INFO]
# LiteLLM completion() model= llama3.2; provider = ollama
# [2026-09-11 22:32:13 -0400] [Agents] [INFO]
# LiteLLM completion() model= llama3.2; provider = ollama
# 22:32:14 - LiteLLM:INFO: utils.py:1302 - Wrapper: Completed Call, calling success_handler
# [2026-09-11 22:32:14 -0400] [Agents] [INFO] Wrapper: Completed Call, calling success_handler
# [2026-09-11 22:32:14 -0400] [Agents] [INFO] Wrapper: Completed Call, calling success_handler
# [2026-09-11 22:32:14 -0400] [Agents] [INFO] [Ensemble Agent] Pre-processed text using ollama/llama3.2
# [2026-09-11 22:32:14 -0400] [Agents] [INFO] [Ensemble Agent] Pre-processed text using ollama/llama3.2
# [2026-09-11 22:32:14 -0400] [Agents] [INFO] [Specialist Agent] Specialist Agent is calling remote fine-tuned model
# [2026-09-11 22:32:14 -0400] [Agents] [INFO] [Specialist Agent] Specialist Agent is calling remote fine-tuned model
# [2026-09-11 22:32:15 -0400] [Agents] [INFO] [Specialist Agent] Specialist Agent completed - predicting $500.00
# [2026-09-11 22:32:15 -0400] [Agents] [INFO] [Specialist Agent] Specialist Agent completed - predicting $500.00
# [2026-09-11 22:32:15 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent is performing a RAG search of the Chroma datastore to find 5 similar products
# [2026-09-11 22:32:15 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent is performing a RAG search of the Chroma datastore to find 5 similar products
# Batches: 100%|████████████████████████████████████| 1/1 [00:00<00:00,  8.22it/s]
# [2026-09-11 22:32:15 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent has found similar products
# [2026-09-11 22:32:15 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent has found similar products
# [2026-09-11 22:32:15 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent is about to call gpt-5.1 with context including 5 similar products
# [2026-09-11 22:32:15 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent is about to call gpt-5.1 with context including 5 similar products
# [2026-09-11 22:32:16 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent completed - predicting $799.00
# [2026-09-11 22:32:16 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent completed - predicting $799.00
# [2026-09-11 22:32:16 -0400] [Agents] [INFO] [Neural Network Agent] Neural Network Agent is starting a prediction
# [2026-09-11 22:32:16 -0400] [Agents] [INFO] [Neural Network Agent] Neural Network Agent is starting a prediction
# [2026-09-11 22:32:16 -0400] [Agents] [INFO] [Neural Network Agent] Neural Network Agent completed - predicting $234.86
# [2026-09-11 22:32:16 -0400] [Agents] [INFO] [Neural Network Agent] Neural Network Agent completed - predicting $234.86
# [2026-09-11 22:32:16 -0400] [Agents] [INFO] [Ensemble Agent] Ensemble Agent complete - returning $712.69
# [2026-09-11 22:32:16 -0400] [Agents] [INFO] [Ensemble Agent] Ensemble Agent complete - returning $712.69
# [2026-09-11 22:32:16 -0400] [Agents] [INFO] [Planning Agent] Planning Agent has processed a deal with discount $68.19
# [2026-09-11 22:32:16 -0400] [Agents] [INFO] [Planning Agent] Planning Agent has processed a deal with discount $68.19
# [2026-09-11 22:32:16 -0400] [Agents] [INFO] [Planning Agent] Planning Agent is pricing up a potential deal
# [2026-09-11 22:32:16 -0400] [Agents] [INFO] [Planning Agent] Planning Agent is pricing up a potential deal
# [2026-09-11 22:32:16 -0400] [Agents] [INFO] [Ensemble Agent] Running Ensemble Agent - preprocessing text
# [2026-09-11 22:32:16 -0400] [Agents] [INFO] [Ensemble Agent] Running Ensemble Agent - preprocessing text
# 22:32:16 - LiteLLM:INFO: utils.py:3421 -
# LiteLLM completion() model= llama3.2; provider = ollama
# [2026-09-11 22:32:16 -0400] [Agents] [INFO]
# LiteLLM completion() model= llama3.2; provider = ollama
# [2026-09-11 22:32:16 -0400] [Agents] [INFO]
# LiteLLM completion() model= llama3.2; provider = ollama
# 22:32:17 - LiteLLM:INFO: utils.py:1302 - Wrapper: Completed Call, calling success_handler
# [2026-09-11 22:32:17 -0400] [Agents] [INFO] Wrapper: Completed Call, calling success_handler
# [2026-09-11 22:32:17 -0400] [Agents] [INFO] Wrapper: Completed Call, calling success_handler
# [2026-09-11 22:32:17 -0400] [Agents] [INFO] [Ensemble Agent] Pre-processed text using ollama/llama3.2
# [2026-09-11 22:32:17 -0400] [Agents] [INFO] [Ensemble Agent] Pre-processed text using ollama/llama3.2
# [2026-09-11 22:32:17 -0400] [Agents] [INFO] [Specialist Agent] Specialist Agent is calling remote fine-tuned model
# [2026-09-11 22:32:17 -0400] [Agents] [INFO] [Specialist Agent] Specialist Agent is calling remote fine-tuned model
# [2026-09-11 22:32:18 -0400] [Agents] [INFO] [Specialist Agent] Specialist Agent completed - predicting $999.00
# [2026-09-11 22:32:18 -0400] [Agents] [INFO] [Specialist Agent] Specialist Agent completed - predicting $999.00
# [2026-09-11 22:32:18 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent is performing a RAG search of the Chroma datastore to find 5 similar products
# [2026-09-11 22:32:18 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent is performing a RAG search of the Chroma datastore to find 5 similar products
# Batches: 100%|████████████████████████████████████| 1/1 [00:00<00:00,  7.77it/s]
# [2026-09-11 22:32:18 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent has found similar products
# [2026-09-11 22:32:18 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent has found similar products
# [2026-09-11 22:32:18 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent is about to call gpt-5.1 with context including 5 similar products
# [2026-09-11 22:32:18 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent is about to call gpt-5.1 with context including 5 similar products
# [2026-09-11 22:32:19 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent completed - predicting $899.00
# [2026-09-11 22:32:19 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent completed - predicting $899.00
# [2026-09-11 22:32:19 -0400] [Agents] [INFO] [Neural Network Agent] Neural Network Agent is starting a prediction
# [2026-09-11 22:32:19 -0400] [Agents] [INFO] [Neural Network Agent] Neural Network Agent is starting a prediction
# [2026-09-11 22:32:19 -0400] [Agents] [INFO] [Neural Network Agent] Neural Network Agent completed - predicting $412.46
# [2026-09-11 22:32:19 -0400] [Agents] [INFO] [Neural Network Agent] Neural Network Agent completed - predicting $412.46
# [2026-09-11 22:32:19 -0400] [Agents] [INFO] [Ensemble Agent] Ensemble Agent complete - returning $860.35
# [2026-09-11 22:32:19 -0400] [Agents] [INFO] [Ensemble Agent] Ensemble Agent complete - returning $860.35
# [2026-09-11 22:32:19 -0400] [Agents] [INFO] [Planning Agent] Planning Agent has processed a deal with discount $260.36
# [2026-09-11 22:32:19 -0400] [Agents] [INFO] [Planning Agent] Planning Agent has processed a deal with discount $260.36
# [2026-09-11 22:32:19 -0400] [Agents] [INFO] [Planning Agent] Planning Agent has identified the best deal has discount $260.36
# [2026-09-11 22:32:19 -0400] [Agents] [INFO] [Planning Agent] Planning Agent has identified the best deal has discount $260.36
# [2026-09-11 22:32:19 -0400] [Agents] [INFO] [Messaging Agent] Messaging Agent is sending a push notification
# [2026-09-11 22:32:19 -0400] [Agents] [INFO] [Messaging Agent] Messaging Agent is sending a push notification
# [2026-09-11 22:32:19 -0400] [Agents] [INFO] [Messaging Agent] Messaging Agent has completed
# [2026-09-11 22:32:19 -0400] [Agents] [INFO] [Messaging Agent] Messaging Agent has completed
# [2026-09-11 22:32:19 -0400] [Agents] [INFO] [Planning Agent] Planning Agent has completed a run
# [2026-09-11 22:32:19 -0400] [Agents] [INFO] [Planning Agent] Planning Agent has completed a run
# [2026-09-11 22:32:19 -0400] [Agents] [INFO] Planning Agent has completed and returned: deal=Deal(product_description='A 16-inch laptop featuring an AMD Ryzen AI 7 processor paired with integrated Radeon graphics, a 16-inch 2K OLED display calibrated to 100% DCI‑P3 color, 16GB of onboard memory, and a 256GB PCIe Gen4 NVMe SSD. It includes a 1080p IR webcam for video calls, a 68 Wh battery with fast-charging support, and ships with Windows 11 Home. The configuration targets users who want a color-accurate OLED panel with capable CPU performance for productivity and multimedia work.', price=599.99, url='https://www.dealnews.com/products/HP/HP-Omni-Book-5-AMD-Ryzen-AI-7-16-Laptop/533399.html?iref=rss-c39') estimate=860.3461853027344 discount=260.3561853027344
# [2026-09-11 22:32:19 -0400] [Agents] [INFO] Planning Agent has completed and returned: deal=Deal(product_description='A 16-inch laptop featuring an AMD Ryzen AI 7 processor paired with integrated Radeon graphics, a 16-inch 2K OLED display calibrated to 100% DCI‑P3 color, 16GB of onboard memory, and a 256GB PCIe Gen4 NVMe SSD. It includes a 1080p IR webcam for video calls, a 68 Wh battery with fast-charging support, and ships with Windows 11 Home. The configuration targets users who want a color-accurate OLED panel with capable CPU performance for productivity and multimedia work.', price=599.99, url='https://www.dealnews.com/products/HP/HP-Omni-Book-5-AMD-Ryzen-AI-7-16-Laptop/533399.html?iref=rss-c39') estimate=860.3461853027344 discount=260.3561853027344
# [2026-09-11 22:35:16 -0400] [Agents] [INFO] Kicking off Planning Agent
# [2026-09-11 22:35:16 -0400] [Agents] [INFO] Kicking off Planning Agent
# [2026-09-11 22:35:16 -0400] [Agents] [INFO] [Planning Agent] Planning Agent is kicking off a run
# [2026-09-11 22:35:16 -0400] [Agents] [INFO] [Planning Agent] Planning Agent is kicking off a run
# [2026-09-11 22:35:16 -0400] [Agents] [INFO] [Scanner Agent] Scanner Agent is about to fetch deals from RSS feed
# [2026-09-11 22:35:16 -0400] [Agents] [INFO] [Scanner Agent] Scanner Agent is about to fetch deals from RSS feed
# [2026-09-11 22:35:32 -0400] [Agents] [INFO] [Scanner Agent] Scanner Agent received 29 deals not already scraped
# [2026-09-11 22:35:32 -0400] [Agents] [INFO] [Scanner Agent] Scanner Agent received 29 deals not already scraped
# [2026-09-11 22:35:32 -0400] [Agents] [INFO] [Scanner Agent] Scanner Agent is calling OpenAI using Structured Outputs
# [2026-09-11 22:35:32 -0400] [Agents] [INFO] [Scanner Agent] Scanner Agent is calling OpenAI using Structured Outputs
# [2026-09-11 22:35:44 -0400] [Agents] [INFO] [Scanner Agent] Scanner Agent received 5 selected deals with price>0 from OpenAI
# [2026-09-11 22:35:44 -0400] [Agents] [INFO] [Scanner Agent] Scanner Agent received 5 selected deals with price>0 from OpenAI
# [2026-09-11 22:35:44 -0400] [Agents] [INFO] [Planning Agent] Planning Agent is pricing up a potential deal
# [2026-09-11 22:35:44 -0400] [Agents] [INFO] [Planning Agent] Planning Agent is pricing up a potential deal
# [2026-09-11 22:35:44 -0400] [Agents] [INFO] [Ensemble Agent] Running Ensemble Agent - preprocessing text
# [2026-09-11 22:35:44 -0400] [Agents] [INFO] [Ensemble Agent] Running Ensemble Agent - preprocessing text
# 22:35:44 - LiteLLM:INFO: utils.py:3421 -
# LiteLLM completion() model= llama3.2; provider = ollama
# [2026-09-11 22:35:44 -0400] [Agents] [INFO]
# LiteLLM completion() model= llama3.2; provider = ollama
# [2026-09-11 22:35:44 -0400] [Agents] [INFO]
# LiteLLM completion() model= llama3.2; provider = ollama
# 22:35:46 - LiteLLM:INFO: utils.py:1302 - Wrapper: Completed Call, calling success_handler
# [2026-09-11 22:35:46 -0400] [Agents] [INFO] Wrapper: Completed Call, calling success_handler
# [2026-09-11 22:35:46 -0400] [Agents] [INFO] Wrapper: Completed Call, calling success_handler
# [2026-09-11 22:35:46 -0400] [Agents] [INFO] [Ensemble Agent] Pre-processed text using ollama/llama3.2
# [2026-09-11 22:35:46 -0400] [Agents] [INFO] [Ensemble Agent] Pre-processed text using ollama/llama3.2
# [2026-09-11 22:35:46 -0400] [Agents] [INFO] [Specialist Agent] Specialist Agent is calling remote fine-tuned model
# [2026-09-11 22:35:46 -0400] [Agents] [INFO] [Specialist Agent] Specialist Agent is calling remote fine-tuned model
# [2026-09-11 22:36:40 -0400] [Agents] [INFO] [Specialist Agent] Specialist Agent completed - predicting $25.00
# [2026-09-11 22:36:40 -0400] [Agents] [INFO] [Specialist Agent] Specialist Agent completed - predicting $25.00
# [2026-09-11 22:36:40 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent is performing a RAG search of the Chroma datastore to find 5 similar products
# [2026-09-11 22:36:40 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent is performing a RAG search of the Chroma datastore to find 5 similar products
# Batches: 100%|████████████████████████████████████| 1/1 [00:00<00:00,  4.06it/s]
# [2026-09-11 22:36:41 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent has found similar products
# [2026-09-11 22:36:41 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent has found similar products
# [2026-09-11 22:36:41 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent is about to call gpt-5.1 with context including 5 similar products
# [2026-09-11 22:36:41 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent is about to call gpt-5.1 with context including 5 similar products
# [2026-09-11 22:36:41 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent completed - predicting $34.99
# [2026-09-11 22:36:41 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent completed - predicting $34.99
# [2026-09-11 22:36:41 -0400] [Agents] [INFO] [Neural Network Agent] Neural Network Agent is starting a prediction
# [2026-09-11 22:36:41 -0400] [Agents] [INFO] [Neural Network Agent] Neural Network Agent is starting a prediction
# [2026-09-11 22:36:41 -0400] [Agents] [INFO] [Neural Network Agent] Neural Network Agent completed - predicting $27.47
# [2026-09-11 22:36:41 -0400] [Agents] [INFO] [Neural Network Agent] Neural Network Agent completed - predicting $27.47
# [2026-09-11 22:36:41 -0400] [Agents] [INFO] [Ensemble Agent] Ensemble Agent complete - returning $33.24
# [2026-09-11 22:36:41 -0400] [Agents] [INFO] [Ensemble Agent] Ensemble Agent complete - returning $33.24
# [2026-09-11 22:36:41 -0400] [Agents] [INFO] [Planning Agent] Planning Agent has processed a deal with discount $21.24
# [2026-09-11 22:36:41 -0400] [Agents] [INFO] [Planning Agent] Planning Agent has processed a deal with discount $21.24
# [2026-09-11 22:36:41 -0400] [Agents] [INFO] [Planning Agent] Planning Agent is pricing up a potential deal
# [2026-09-11 22:36:41 -0400] [Agents] [INFO] [Planning Agent] Planning Agent is pricing up a potential deal
# [2026-09-11 22:36:41 -0400] [Agents] [INFO] [Ensemble Agent] Running Ensemble Agent - preprocessing text
# [2026-09-11 22:36:41 -0400] [Agents] [INFO] [Ensemble Agent] Running Ensemble Agent - preprocessing text
# 22:36:41 - LiteLLM:INFO: utils.py:3421 -
# LiteLLM completion() model= llama3.2; provider = ollama
# [2026-09-11 22:36:41 -0400] [Agents] [INFO]
# LiteLLM completion() model= llama3.2; provider = ollama
# [2026-09-11 22:36:41 -0400] [Agents] [INFO]
# LiteLLM completion() model= llama3.2; provider = ollama
# 22:36:43 - LiteLLM:INFO: utils.py:1302 - Wrapper: Completed Call, calling success_handler
# [2026-09-11 22:36:43 -0400] [Agents] [INFO] Wrapper: Completed Call, calling success_handler
# [2026-09-11 22:36:43 -0400] [Agents] [INFO] Wrapper: Completed Call, calling success_handler
# [2026-09-11 22:36:43 -0400] [Agents] [INFO] [Ensemble Agent] Pre-processed text using ollama/llama3.2
# [2026-09-11 22:36:43 -0400] [Agents] [INFO] [Ensemble Agent] Pre-processed text using ollama/llama3.2
# [2026-09-11 22:36:43 -0400] [Agents] [INFO] [Specialist Agent] Specialist Agent is calling remote fine-tuned model
# [2026-09-11 22:36:43 -0400] [Agents] [INFO] [Specialist Agent] Specialist Agent is calling remote fine-tuned model
# [2026-09-11 22:36:43 -0400] [Agents] [INFO] [Specialist Agent] Specialist Agent completed - predicting $40.00
# [2026-09-11 22:36:43 -0400] [Agents] [INFO] [Specialist Agent] Specialist Agent completed - predicting $40.00
# [2026-09-11 22:36:43 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent is performing a RAG search of the Chroma datastore to find 5 similar products
# [2026-09-11 22:36:43 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent is performing a RAG search of the Chroma datastore to find 5 similar products
# Batches: 100%|████████████████████████████████████| 1/1 [00:00<00:00, 22.49it/s]
# [2026-09-11 22:36:43 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent has found similar products
# [2026-09-11 22:36:43 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent has found similar products
# [2026-09-11 22:36:43 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent is about to call gpt-5.1 with context including 5 similar products
# [2026-09-11 22:36:43 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent is about to call gpt-5.1 with context including 5 similar products
# [2026-09-11 22:36:44 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent completed - predicting $32.99
# [2026-09-11 22:36:44 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent completed - predicting $32.99
# [2026-09-11 22:36:44 -0400] [Agents] [INFO] [Neural Network Agent] Neural Network Agent is starting a prediction
# [2026-09-11 22:36:44 -0400] [Agents] [INFO] [Neural Network Agent] Neural Network Agent is starting a prediction
# [2026-09-11 22:36:44 -0400] [Agents] [INFO] [Neural Network Agent] Neural Network Agent completed - predicting $47.82
# [2026-09-11 22:36:44 -0400] [Agents] [INFO] [Neural Network Agent] Neural Network Agent completed - predicting $47.82
# [2026-09-11 22:36:44 -0400] [Agents] [INFO] [Ensemble Agent] Ensemble Agent complete - returning $35.17
# [2026-09-11 22:36:44 -0400] [Agents] [INFO] [Ensemble Agent] Ensemble Agent complete - returning $35.17
# [2026-09-11 22:36:44 -0400] [Agents] [INFO] [Planning Agent] Planning Agent has processed a deal with discount $9.18
# [2026-09-11 22:36:44 -0400] [Agents] [INFO] [Planning Agent] Planning Agent has processed a deal with discount $9.18
# [2026-09-11 22:36:44 -0400] [Agents] [INFO] [Planning Agent] Planning Agent is pricing up a potential deal
# [2026-09-11 22:36:44 -0400] [Agents] [INFO] [Planning Agent] Planning Agent is pricing up a potential deal
# [2026-09-11 22:36:44 -0400] [Agents] [INFO] [Ensemble Agent] Running Ensemble Agent - preprocessing text
# [2026-09-11 22:36:44 -0400] [Agents] [INFO] [Ensemble Agent] Running Ensemble Agent - preprocessing text
# 22:36:44 - LiteLLM:INFO: utils.py:3421 -
# LiteLLM completion() model= llama3.2; provider = ollama
# [2026-09-11 22:36:44 -0400] [Agents] [INFO]
# LiteLLM completion() model= llama3.2; provider = ollama
# [2026-09-11 22:36:44 -0400] [Agents] [INFO]
# LiteLLM completion() model= llama3.2; provider = ollama
# 22:36:46 - LiteLLM:INFO: utils.py:1302 - Wrapper: Completed Call, calling success_handler
# [2026-09-11 22:36:46 -0400] [Agents] [INFO] Wrapper: Completed Call, calling success_handler
# [2026-09-11 22:36:46 -0400] [Agents] [INFO] Wrapper: Completed Call, calling success_handler
# [2026-09-11 22:36:46 -0400] [Agents] [INFO] [Ensemble Agent] Pre-processed text using ollama/llama3.2
# [2026-09-11 22:36:46 -0400] [Agents] [INFO] [Ensemble Agent] Pre-processed text using ollama/llama3.2
# [2026-09-11 22:36:46 -0400] [Agents] [INFO] [Specialist Agent] Specialist Agent is calling remote fine-tuned model
# [2026-09-11 22:36:46 -0400] [Agents] [INFO] [Specialist Agent] Specialist Agent is calling remote fine-tuned model
# [2026-09-11 22:36:47 -0400] [Agents] [INFO] [Specialist Agent] Specialist Agent completed - predicting $60.00
# [2026-09-11 22:36:47 -0400] [Agents] [INFO] [Specialist Agent] Specialist Agent completed - predicting $60.00
# [2026-09-11 22:36:47 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent is performing a RAG search of the Chroma datastore to find 5 similar products
# [2026-09-11 22:36:47 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent is performing a RAG search of the Chroma datastore to find 5 similar products
# Batches: 100%|████████████████████████████████████| 1/1 [00:00<00:00,  5.26it/s]
# [2026-09-11 22:36:47 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent has found similar products
# [2026-09-11 22:36:47 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent has found similar products
# [2026-09-11 22:36:47 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent is about to call gpt-5.1 with context including 5 similar products
# [2026-09-11 22:36:47 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent is about to call gpt-5.1 with context including 5 similar products
# [2026-09-11 22:36:48 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent completed - predicting $89.99
# [2026-09-11 22:36:48 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent completed - predicting $89.99
# [2026-09-11 22:36:48 -0400] [Agents] [INFO] [Neural Network Agent] Neural Network Agent is starting a prediction
# [2026-09-11 22:36:48 -0400] [Agents] [INFO] [Neural Network Agent] Neural Network Agent is starting a prediction
# [2026-09-11 22:36:48 -0400] [Agents] [INFO] [Neural Network Agent] Neural Network Agent completed - predicting $71.89
# [2026-09-11 22:36:48 -0400] [Agents] [INFO] [Neural Network Agent] Neural Network Agent completed - predicting $71.89
# [2026-09-11 22:36:48 -0400] [Agents] [INFO] [Ensemble Agent] Ensemble Agent complete - returning $85.18
# [2026-09-11 22:36:48 -0400] [Agents] [INFO] [Ensemble Agent] Ensemble Agent complete - returning $85.18
# [2026-09-11 22:36:48 -0400] [Agents] [INFO] [Planning Agent] Planning Agent has processed a deal with discount $55.23
# [2026-09-11 22:36:48 -0400] [Agents] [INFO] [Planning Agent] Planning Agent has processed a deal with discount $55.23
# [2026-09-11 22:36:48 -0400] [Agents] [INFO] [Planning Agent] Planning Agent is pricing up a potential deal
# [2026-09-11 22:36:48 -0400] [Agents] [INFO] [Planning Agent] Planning Agent is pricing up a potential deal
# [2026-09-11 22:36:48 -0400] [Agents] [INFO] [Ensemble Agent] Running Ensemble Agent - preprocessing text
# [2026-09-11 22:36:48 -0400] [Agents] [INFO] [Ensemble Agent] Running Ensemble Agent - preprocessing text
# 22:36:48 - LiteLLM:INFO: utils.py:3421 -
# LiteLLM completion() model= llama3.2; provider = ollama
# [2026-09-11 22:36:48 -0400] [Agents] [INFO]
# LiteLLM completion() model= llama3.2; provider = ollama
# [2026-09-11 22:36:48 -0400] [Agents] [INFO]
# LiteLLM completion() model= llama3.2; provider = ollama
# 22:36:49 - LiteLLM:INFO: utils.py:1302 - Wrapper: Completed Call, calling success_handler
# [2026-09-11 22:36:49 -0400] [Agents] [INFO] Wrapper: Completed Call, calling success_handler
# [2026-09-11 22:36:49 -0400] [Agents] [INFO] Wrapper: Completed Call, calling success_handler
# [2026-09-11 22:36:49 -0400] [Agents] [INFO] [Ensemble Agent] Pre-processed text using ollama/llama3.2
# [2026-09-11 22:36:49 -0400] [Agents] [INFO] [Ensemble Agent] Pre-processed text using ollama/llama3.2
# [2026-09-11 22:36:49 -0400] [Agents] [INFO] [Specialist Agent] Specialist Agent is calling remote fine-tuned model
# [2026-09-11 22:36:49 -0400] [Agents] [INFO] [Specialist Agent] Specialist Agent is calling remote fine-tuned model
# [2026-09-11 22:36:50 -0400] [Agents] [INFO] [Specialist Agent] Specialist Agent completed - predicting $500.00
# [2026-09-11 22:36:50 -0400] [Agents] [INFO] [Specialist Agent] Specialist Agent completed - predicting $500.00
# [2026-09-11 22:36:50 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent is performing a RAG search of the Chroma datastore to find 5 similar products
# [2026-09-11 22:36:50 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent is performing a RAG search of the Chroma datastore to find 5 similar products
# Batches: 100%|████████████████████████████████████| 1/1 [00:00<00:00, 10.68it/s]
# [2026-09-11 22:36:50 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent has found similar products
# [2026-09-11 22:36:50 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent has found similar products
# [2026-09-11 22:36:50 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent is about to call gpt-5.1 with context including 5 similar products
# [2026-09-11 22:36:50 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent is about to call gpt-5.1 with context including 5 similar products
# [2026-09-11 22:36:51 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent completed - predicting $449.00
# [2026-09-11 22:36:51 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent completed - predicting $449.00
# [2026-09-11 22:36:51 -0400] [Agents] [INFO] [Neural Network Agent] Neural Network Agent is starting a prediction
# [2026-09-11 22:36:51 -0400] [Agents] [INFO] [Neural Network Agent] Neural Network Agent is starting a prediction
# [2026-09-11 22:36:51 -0400] [Agents] [INFO] [Neural Network Agent] Neural Network Agent completed - predicting $331.31
# [2026-09-11 22:36:51 -0400] [Agents] [INFO] [Neural Network Agent] Neural Network Agent completed - predicting $331.31
# [2026-09-11 22:36:51 -0400] [Agents] [INFO] [Ensemble Agent] Ensemble Agent complete - returning $442.33
# [2026-09-11 22:36:51 -0400] [Agents] [INFO] [Ensemble Agent] Ensemble Agent complete - returning $442.33
# [2026-09-11 22:36:51 -0400] [Agents] [INFO] [Planning Agent] Planning Agent has processed a deal with discount $-202.17
# [2026-09-11 22:36:51 -0400] [Agents] [INFO] [Planning Agent] Planning Agent has processed a deal with discount $-202.17
# [2026-09-11 22:36:51 -0400] [Agents] [INFO] [Planning Agent] Planning Agent is pricing up a potential deal
# [2026-09-11 22:36:51 -0400] [Agents] [INFO] [Planning Agent] Planning Agent is pricing up a potential deal
# [2026-09-11 22:36:51 -0400] [Agents] [INFO] [Ensemble Agent] Running Ensemble Agent - preprocessing text
# [2026-09-11 22:36:51 -0400] [Agents] [INFO] [Ensemble Agent] Running Ensemble Agent - preprocessing text
# 22:36:51 - LiteLLM:INFO: utils.py:3421 -
# LiteLLM completion() model= llama3.2; provider = ollama
# [2026-09-11 22:36:51 -0400] [Agents] [INFO]
# LiteLLM completion() model= llama3.2; provider = ollama
# [2026-09-11 22:36:51 -0400] [Agents] [INFO]
# LiteLLM completion() model= llama3.2; provider = ollama
# 22:36:53 - LiteLLM:INFO: utils.py:1302 - Wrapper: Completed Call, calling success_handler
# [2026-09-11 22:36:53 -0400] [Agents] [INFO] Wrapper: Completed Call, calling success_handler
# [2026-09-11 22:36:53 -0400] [Agents] [INFO] Wrapper: Completed Call, calling success_handler
# [2026-09-11 22:36:53 -0400] [Agents] [INFO] [Ensemble Agent] Pre-processed text using ollama/llama3.2
# [2026-09-11 22:36:53 -0400] [Agents] [INFO] [Ensemble Agent] Pre-processed text using ollama/llama3.2
# [2026-09-11 22:36:53 -0400] [Agents] [INFO] [Specialist Agent] Specialist Agent is calling remote fine-tuned model
# [2026-09-11 22:36:53 -0400] [Agents] [INFO] [Specialist Agent] Specialist Agent is calling remote fine-tuned model
# [2026-09-11 22:36:54 -0400] [Agents] [INFO] [Specialist Agent] Specialist Agent completed - predicting $500.00
# [2026-09-11 22:36:54 -0400] [Agents] [INFO] [Specialist Agent] Specialist Agent completed - predicting $500.00
# [2026-09-11 22:36:54 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent is performing a RAG search of the Chroma datastore to find 5 similar products
# [2026-09-11 22:36:54 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent is performing a RAG search of the Chroma datastore to find 5 similar products
# Batches: 100%|████████████████████████████████████| 1/1 [00:00<00:00,  3.79it/s]
# [2026-09-11 22:36:54 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent has found similar products
# [2026-09-11 22:36:54 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent has found similar products
# [2026-09-11 22:36:54 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent is about to call gpt-5.1 with context including 5 similar products
# [2026-09-11 22:36:54 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent is about to call gpt-5.1 with context including 5 similar products
# [2026-09-11 22:36:55 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent completed - predicting $899.00
# [2026-09-11 22:36:55 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent completed - predicting $899.00
# [2026-09-11 22:36:55 -0400] [Agents] [INFO] [Neural Network Agent] Neural Network Agent is starting a prediction
# [2026-09-11 22:36:55 -0400] [Agents] [INFO] [Neural Network Agent] Neural Network Agent is starting a prediction
# [2026-09-11 22:36:55 -0400] [Agents] [INFO] [Neural Network Agent] Neural Network Agent completed - predicting $151.62
# [2026-09-11 22:36:55 -0400] [Agents] [INFO] [Neural Network Agent] Neural Network Agent completed - predicting $151.62
# [2026-09-11 22:36:55 -0400] [Agents] [INFO] [Ensemble Agent] Ensemble Agent complete - returning $784.36
# [2026-09-11 22:36:55 -0400] [Agents] [INFO] [Ensemble Agent] Ensemble Agent complete - returning $784.36
# [2026-09-11 22:36:55 -0400] [Agents] [INFO] [Planning Agent] Planning Agent has processed a deal with discount $160.36
# [2026-09-11 22:36:55 -0400] [Agents] [INFO] [Planning Agent] Planning Agent has processed a deal with discount $160.36
# [2026-09-11 22:36:55 -0400] [Agents] [INFO] [Planning Agent] Planning Agent has identified the best deal has discount $160.36
# [2026-09-11 22:36:55 -0400] [Agents] [INFO] [Planning Agent] Planning Agent has identified the best deal has discount $160.36
# [2026-09-11 22:36:55 -0400] [Agents] [INFO] [Messaging Agent] Messaging Agent is sending a push notification
# [2026-09-11 22:36:55 -0400] [Agents] [INFO] [Messaging Agent] Messaging Agent is sending a push notification
# [2026-09-11 22:36:55 -0400] [Agents] [INFO] [Messaging Agent] Messaging Agent has completed
# [2026-09-11 22:36:55 -0400] [Agents] [INFO] [Messaging Agent] Messaging Agent has completed
# [2026-09-11 22:36:55 -0400] [Agents] [INFO] [Planning Agent] Planning Agent has completed a run
# [2026-09-11 22:36:55 -0400] [Agents] [INFO] [Planning Agent] Planning Agent has completed a run
# [2026-09-11 22:36:55 -0400] [Agents] [INFO] Planning Agent has completed and returned: deal=Deal(product_description='Google Pixel 11 (256GB) through Mint Mobile is a full‑featured Android smartphone with a 6.3" Actua OLED display (1080 x 2424), Google Tensor G6 chipset, triple rear camera array (48MP + 10.8MP + 13MP) and a 10.5MP front camera. It includes 256GB of built-in storage, eSIM-only support, and a large non-removable battery. The device is offered bundled with service but the standalone phone price listed is $624.', price=624.0, url='https://www.dealnews.com/Google-Pixel-11-256-GB-Mint-Mobile-Android-Smartphone-for-624-1-year-of-Unlimited-for-15-month-free-shipping/22169568.html?iref=rss-c142') estimate=784.3621612548828 discount=160.36216125488284
# [2026-09-11 22:36:55 -0400] [Agents] [INFO] Planning Agent has completed and returned: deal=Deal(product_description='Google Pixel 11 (256GB) through Mint Mobile is a full‑featured Android smartphone with a 6.3" Actua OLED display (1080 x 2424), Google Tensor G6 chipset, triple rear camera array (48MP + 10.8MP + 13MP) and a 10.5MP front camera. It includes 256GB of built-in storage, eSIM-only support, and a large non-removable battery. The device is offered bundled with service but the standalone phone price listed is $624.', price=624.0, url='https://www.dealnews.com/Google-Pixel-11-256-GB-Mint-Mobile-Android-Smartphone-for-624-1-year-of-Unlimited-for-15-month-free-shipping/22169568.html?iref=rss-c142') estimate=784.3621612548828 discount=160.36216125488284
# [2026-09-11 22:40:16 -0400] [Agents] [INFO] Kicking off Planning Agent
# [2026-09-11 22:40:16 -0400] [Agents] [INFO] Kicking off Planning Agent
# [2026-09-11 22:40:16 -0400] [Agents] [INFO] [Planning Agent] Planning Agent is kicking off a run
# [2026-09-11 22:40:16 -0400] [Agents] [INFO] [Planning Agent] Planning Agent is kicking off a run
# ...
# [2026-09-11 22:41:22 -0400] [Agents] [INFO] [Ensemble Agent] Pre-processed text using ollama/llama3.2
# [2026-09-11 22:41:22 -0400] [Agents] [INFO] [Ensemble Agent] Pre-processed text using ollama/llama3.2
# [2026-09-11 22:41:22 -0400] [Agents] [INFO] [Specialist Agent] Specialist Agent is calling remote fine-tuned model
# [2026-09-11 22:41:22 -0400] [Agents] [INFO] [Specialist Agent] Specialist Agent is calling remote fine-tuned model
# [2026-09-11 22:41:23 -0400] [Agents] [INFO] [Specialist Agent] Specialist Agent completed - predicting $25.00
# [2026-09-11 22:41:23 -0400] [Agents] [INFO] [Specialist Agent] Specialist Agent completed - predicting $25.00
# [2026-09-11 22:41:23 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent is performing a RAG search of the Chroma datastore to find 5 similar products
# [2026-09-11 22:41:23 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent is performing a RAG search of the Chroma datastore to find 5 similar products
# Batches: 100%|████████████████████████████████████| 1/1 [00:00<00:00,  5.23it/s]
# [2026-09-11 22:41:23 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent has found similar products
# [2026-09-11 22:41:23 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent has found similar products
# [2026-09-11 22:41:23 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent is about to call gpt-5.1 with context including 5 similar products
# [2026-09-11 22:41:23 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent is about to call gpt-5.1 with context including 5 similar products
# [2026-09-11 22:41:24 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent completed - predicting $49.99
# [2026-09-11 22:41:24 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent completed - predicting $49.99
# [2026-09-11 22:41:24 -0400] [Agents] [INFO] [Neural Network Agent] Neural Network Agent is starting a prediction
# [2026-09-11 22:41:24 -0400] [Agents] [INFO] [Neural Network Agent] Neural Network Agent is starting a prediction
# [2026-09-11 22:41:24 -0400] [Agents] [INFO] [Neural Network Agent] Neural Network Agent completed - predicting $27.79
# [2026-09-11 22:41:24 -0400] [Agents] [INFO] [Neural Network Agent] Neural Network Agent completed - predicting $27.79
# [2026-09-11 22:41:24 -0400] [Agents] [INFO] [Ensemble Agent] Ensemble Agent complete - returning $45.27
# [2026-09-11 22:41:24 -0400] [Agents] [INFO] [Ensemble Agent] Ensemble Agent complete - returning $45.27
# [2026-09-11 22:41:24 -0400] [Agents] [INFO] [Planning Agent] Planning Agent has processed a deal with discount $19.28
# [2026-09-11 22:41:24 -0400] [Agents] [INFO] [Planning Agent] Planning Agent has processed a deal with discount $19.28
# [2026-09-11 22:41:24 -0400] [Agents] [INFO] [Planning Agent] Planning Agent is pricing up a potential deal
# [2026-09-11 22:41:24 -0400] [Agents] [INFO] [Planning Agent] Planning Agent is pricing up a potential deal
# [2026-09-11 22:41:24 -0400] [Agents] [INFO] [Ensemble Agent] Running Ensemble Agent - preprocessing text
# [2026-09-11 22:41:24 -0400] [Agents] [INFO] [Ensemble Agent] Running Ensemble Agent - preprocessing text
# 22:41:24 - LiteLLM:INFO: utils.py:3421 -
# LiteLLM completion() model= llama3.2; provider = ollama
# [2026-09-11 22:41:24 -0400] [Agents] [INFO]
# LiteLLM completion() model= llama3.2; provider = ollama
# [2026-09-11 22:41:24 -0400] [Agents] [INFO]
# LiteLLM completion() model= llama3.2; provider = ollama
# 22:41:25 - LiteLLM:INFO: utils.py:1302 - Wrapper: Completed Call, calling success_handler
# [2026-09-11 22:41:25 -0400] [Agents] [INFO] Wrapper: Completed Call, calling success_handler
# [2026-09-11 22:41:25 -0400] [Agents] [INFO] Wrapper: Completed Call, calling success_handler
# [2026-09-11 22:41:25 -0400] [Agents] [INFO] [Ensemble Agent] Pre-processed text using ollama/llama3.2
# [2026-09-11 22:41:25 -0400] [Agents] [INFO] [Ensemble Agent] Pre-processed text using ollama/llama3.2
# [2026-09-11 22:41:25 -0400] [Agents] [INFO] [Specialist Agent] Specialist Agent is calling remote fine-tuned model
# [2026-09-11 22:41:25 -0400] [Agents] [INFO] [Specialist Agent] Specialist Agent is calling remote fine-tuned model
# [2026-09-11 22:41:26 -0400] [Agents] [INFO] [Specialist Agent] Specialist Agent completed - predicting $110.00
# [2026-09-11 22:41:26 -0400] [Agents] [INFO] [Specialist Agent] Specialist Agent completed - predicting $110.00
# [2026-09-11 22:41:26 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent is performing a RAG search of the Chroma datastore to find 5 similar products
# [2026-09-11 22:41:26 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent is performing a RAG search of the Chroma datastore to find 5 similar products
# Batches: 100%|████████████████████████████████████| 1/1 [00:00<00:00,  8.41it/s]
# [2026-09-11 22:41:26 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent has found similar products
# [2026-09-11 22:41:26 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent has found similar products
# [2026-09-11 22:41:26 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent is about to call gpt-5.1 with context including 5 similar products
# [2026-09-11 22:41:26 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent is about to call gpt-5.1 with context including 5 similar products
# [2026-09-11 22:41:27 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent completed - predicting $129.99
# [2026-09-11 22:41:27 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent completed - predicting $129.99
# [2026-09-11 22:41:27 -0400] [Agents] [INFO] [Neural Network Agent] Neural Network Agent is starting a prediction
# [2026-09-11 22:41:27 -0400] [Agents] [INFO] [Neural Network Agent] Neural Network Agent is starting a prediction
# [2026-09-11 22:41:27 -0400] [Agents] [INFO] [Neural Network Agent] Neural Network Agent completed - predicting $131.73
# [2026-09-11 22:41:27 -0400] [Agents] [INFO] [Neural Network Agent] Neural Network Agent completed - predicting $131.73
# [2026-09-11 22:41:27 -0400] [Agents] [INFO] [Ensemble Agent] Ensemble Agent complete - returning $128.17
# [2026-09-11 22:41:27 -0400] [Agents] [INFO] [Ensemble Agent] Ensemble Agent complete - returning $128.17
# [2026-09-11 22:41:27 -0400] [Agents] [INFO] [Planning Agent] Planning Agent has processed a deal with discount $98.22
# [2026-09-11 22:41:27 -0400] [Agents] [INFO] [Planning Agent] Planning Agent has processed a deal with discount $98.22
# [2026-09-11 22:41:27 -0400] [Agents] [INFO] [Planning Agent] Planning Agent is pricing up a potential deal
# [2026-09-11 22:41:27 -0400] [Agents] [INFO] [Planning Agent] Planning Agent is pricing up a potential deal
# [2026-09-11 22:41:27 -0400] [Agents] [INFO] [Ensemble Agent] Running Ensemble Agent - preprocessing text
# [2026-09-11 22:41:27 -0400] [Agents] [INFO] [Ensemble Agent] Running Ensemble Agent - preprocessing text
# 22:41:27 - LiteLLM:INFO: utils.py:3421 -
# LiteLLM completion() model= llama3.2; provider = ollama
# [2026-09-11 22:41:27 -0400] [Agents] [INFO]
# LiteLLM completion() model= llama3.2; provider = ollama
# [2026-09-11 22:41:27 -0400] [Agents] [INFO]
# LiteLLM completion() model= llama3.2; provider = ollama
# 22:41:29 - LiteLLM:INFO: utils.py:1302 - Wrapper: Completed Call, calling success_handler
# [2026-09-11 22:41:29 -0400] [Agents] [INFO] Wrapper: Completed Call, calling success_handler
# [2026-09-11 22:41:29 -0400] [Agents] [INFO] Wrapper: Completed Call, calling success_handler
# [2026-09-11 22:41:29 -0400] [Agents] [INFO] [Ensemble Agent] Pre-processed text using ollama/llama3.2
# [2026-09-11 22:41:29 -0400] [Agents] [INFO] [Ensemble Agent] Pre-processed text using ollama/llama3.2
# [2026-09-11 22:41:29 -0400] [Agents] [INFO] [Specialist Agent] Specialist Agent is calling remote fine-tuned model
# [2026-09-11 22:41:29 -0400] [Agents] [INFO] [Specialist Agent] Specialist Agent is calling remote fine-tuned model
# [2026-09-11 22:41:29 -0400] [Agents] [INFO] [Specialist Agent] Specialist Agent completed - predicting $299.00
# [2026-09-11 22:41:29 -0400] [Agents] [INFO] [Specialist Agent] Specialist Agent completed - predicting $299.00
# [2026-09-11 22:41:29 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent is performing a RAG search of the Chroma datastore to find 5 similar products
# [2026-09-11 22:41:29 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent is performing a RAG search of the Chroma datastore to find 5 similar products
# Batches: 100%|████████████████████████████████████| 1/1 [00:00<00:00, 13.95it/s]
# [2026-09-11 22:41:30 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent has found similar products
# [2026-09-11 22:41:30 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent has found similar products
# [2026-09-11 22:41:30 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent is about to call gpt-5.1 with context including 5 similar products
# [2026-09-11 22:41:30 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent is about to call gpt-5.1 with context including 5 similar products
# [2026-09-11 22:41:30 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent completed - predicting $199.99
# [2026-09-11 22:41:30 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent completed - predicting $199.99
# [2026-09-11 22:41:30 -0400] [Agents] [INFO] [Neural Network Agent] Neural Network Agent is starting a prediction
# [2026-09-11 22:41:30 -0400] [Agents] [INFO] [Neural Network Agent] Neural Network Agent is starting a prediction
# [2026-09-11 22:41:30 -0400] [Agents] [INFO] [Neural Network Agent] Neural Network Agent completed - predicting $232.15
# [2026-09-11 22:41:30 -0400] [Agents] [INFO] [Neural Network Agent] Neural Network Agent completed - predicting $232.15
# [2026-09-11 22:41:30 -0400] [Agents] [INFO] [Ensemble Agent] Ensemble Agent complete - returning $213.11
# [2026-09-11 22:41:30 -0400] [Agents] [INFO] [Ensemble Agent] Ensemble Agent complete - returning $213.11
# [2026-09-11 22:41:30 -0400] [Agents] [INFO] [Planning Agent] Planning Agent has processed a deal with discount $153.13
# [2026-09-11 22:41:30 -0400] [Agents] [INFO] [Planning Agent] Planning Agent has processed a deal with discount $153.13
# [2026-09-11 22:41:30 -0400] [Agents] [INFO] [Planning Agent] Planning Agent is pricing up a potential deal
# [2026-09-11 22:41:30 -0400] [Agents] [INFO] [Planning Agent] Planning Agent is pricing up a potential deal
# [2026-09-11 22:41:30 -0400] [Agents] [INFO] [Ensemble Agent] Running Ensemble Agent - preprocessing text
# [2026-09-11 22:41:30 -0400] [Agents] [INFO] [Ensemble Agent] Running Ensemble Agent - preprocessing text
# 22:41:30 - LiteLLM:INFO: utils.py:3421 -
# LiteLLM completion() model= llama3.2; provider = ollama
# [2026-09-11 22:41:30 -0400] [Agents] [INFO]
# LiteLLM completion() model= llama3.2; provider = ollama
# [2026-09-11 22:41:30 -0400] [Agents] [INFO]
# LiteLLM completion() model= llama3.2; provider = ollama
# 22:41:32 - LiteLLM:INFO: utils.py:1302 - Wrapper: Completed Call, calling success_handler
# [2026-09-11 22:41:32 -0400] [Agents] [INFO] Wrapper: Completed Call, calling success_handler
# [2026-09-11 22:41:32 -0400] [Agents] [INFO] Wrapper: Completed Call, calling success_handler
# [2026-09-11 22:41:32 -0400] [Agents] [INFO] [Ensemble Agent] Pre-processed text using ollama/llama3.2
# [2026-09-11 22:41:32 -0400] [Agents] [INFO] [Ensemble Agent] Pre-processed text using ollama/llama3.2
# [2026-09-11 22:41:32 -0400] [Agents] [INFO] [Specialist Agent] Specialist Agent is calling remote fine-tuned model
# [2026-09-11 22:41:32 -0400] [Agents] [INFO] [Specialist Agent] Specialist Agent is calling remote fine-tuned model
# [2026-09-11 22:41:33 -0400] [Agents] [INFO] [Specialist Agent] Specialist Agent completed - predicting $950.00
# [2026-09-11 22:41:33 -0400] [Agents] [INFO] [Specialist Agent] Specialist Agent completed - predicting $950.00
# [2026-09-11 22:41:33 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent is performing a RAG search of the Chroma datastore to find 5 similar products
# [2026-09-11 22:41:33 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent is performing a RAG search of the Chroma datastore to find 5 similar products
# Batches: 100%|████████████████████████████████████| 1/1 [00:00<00:00, 18.60it/s]
# [2026-09-11 22:41:33 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent has found similar products
# [2026-09-11 22:41:33 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent has found similar products
# [2026-09-11 22:41:33 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent is about to call gpt-5.1 with context including 5 similar products
# [2026-09-11 22:41:33 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent is about to call gpt-5.1 with context including 5 similar products
# [2026-09-11 22:41:33 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent completed - predicting $1199.00
# [2026-09-11 22:41:33 -0400] [Agents] [INFO] [Frontier Agent] Frontier Agent completed - predicting $1199.00
# [2026-09-11 22:41:33 -0400] [Agents] [INFO] [Neural Network Agent] Neural Network Agent is starting a prediction
# [2026-09-11 22:41:33 -0400] [Agents] [INFO] [Neural Network Agent] Neural Network Agent is starting a prediction
# [2026-09-11 22:41:33 -0400] [Agents] [INFO] [Neural Network Agent] Neural Network Agent completed - predicting $557.21
# [2026-09-11 22:41:33 -0400] [Agents] [INFO] [Neural Network Agent] Neural Network Agent completed - predicting $557.21
# [2026-09-11 22:41:33 -0400] [Agents] [INFO] [Ensemble Agent] Ensemble Agent complete - returning $1109.92
# [2026-09-11 22:41:33 -0400] [Agents] [INFO] [Ensemble Agent] Ensemble Agent complete - returning $1109.92
# [2026-09-11 22:41:33 -0400] [Agents] [INFO] [Planning Agent] Planning Agent has processed a deal with discount $465.42
# [2026-09-11 22:41:33 -0400] [Agents] [INFO] [Planning Agent] Planning Agent has processed a deal with discount $465.42
# [2026-09-11 22:41:33 -0400] [Agents] [INFO] [Planning Agent] Planning Agent has identified the best deal has discount $465.42
# [2026-09-11 22:41:33 -0400] [Agents] [INFO] [Planning Agent] Planning Agent has identified the best deal has discount $465.42
# [2026-09-11 22:41:33 -0400] [Agents] [INFO] [Messaging Agent] Messaging Agent is sending a push notification
# [2026-09-11 22:41:33 -0400] [Agents] [INFO] [Messaging Agent] Messaging Agent is sending a push notification
# [2026-09-11 22:41:34 -0400] [Agents] [INFO] [Messaging Agent] Messaging Agent has completed
# [2026-09-11 22:41:34 -0400] [Agents] [INFO] [Messaging Agent] Messaging Agent has completed
# [2026-09-11 22:41:34 -0400] [Agents] [INFO] [Planning Agent] Planning Agent has completed a run
# [2026-09-11 22:41:34 -0400] [Agents] [INFO] [Planning Agent] Planning Agent has completed a run
# [2026-09-11 22:41:34 -0400] [Agents] [INFO] Planning Agent has completed and returned: deal=Deal(product_description='A freestanding 43-inch digital signage display with a durable floor-stand design for easy repositioning in lobbies or retail spaces. It runs Android OS with cloud-based content management, supports split-screen multi-content display, and offers flexible connectivity via USB, HDMI, and 5G Wi‑Fi. The screen is a 600-nit IPS touchscreen suitable for high-traffic environments and includes commercial-grade build features.', price=644.5, url='https://www.dealnews.com/products/Jaszdot/Jaszdot-43-Floor-Standing-Digital-Signage-Display/529399.html?iref=rss-c142') estimate=1109.9207092285158 discount=465.42070922851576
# [2026-09-11 22:41:34 -0400] [Agents] [INFO] Planning Agent has completed and returned: deal=Deal(product_description='A freestanding 43-inch digital signage display with a durable floor-stand design for easy repositioning in lobbies or retail spaces. It runs Android OS with cloud-based content management, supports split-screen multi-content display, and offers flexible connectivity via USB, HDMI, and 5G Wi‑Fi. The screen is a 600-nit IPS touchscreen suitable for high-traffic environments and includes commercial-grade build features.', price=644.5, url='https://www.dealnews.com/products/Jaszdot/Jaszdot-43-Floor-Standing-Digital-Signage-Display/529399.html?iref=rss-c142') estimate=1109.9207092285158 discount=465.42070922851576

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#a22;">But wait!! There's more..</h2>
#             <span style="color:#a22;">If you're not fed up of product prices yet 😂 I've built this out some more!<br/>
#             If you look in my repo <a href="https://github.com/ed-donner/tech2ai">tech2ai</a>, in segment4 is a version that uses OpenAI Agents SDK for the AutonomousPlanningAgent, and makes use of MCP servers.  If you're intrigued by Agents and MCP, and would like to learn more, then I also have a companion course on this. This, along with my 2 other companion courses, are laid out in my <a href="https://edwarddonner.com/2025/05/28/connecting-my-courses-become-an-llm-expert-and-leader/">complete AI curriculum</a>.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/thankyou.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#090;">CONGRATULATIONS AND THANK YOU!!!</h2>
#             <span style="color:#090;">
#                 It's so fabulous that you've made it to the very end! My heartiest congratulations. Please stay in touch! I'm <a href="https://www.linkedin.com/in/eddonner/">here on LinkedIn</a> if we're not already connected and I'm on X at <a href="https://x.com/edwarddonner">@edwarddonner</a>. And my editor would be cross with me if I didn't mention one more time: it makes a HUGE difference when students rate this course on Udemy - it's one of the main ways that Udemy decides whether to show it to others. <br/><br/>Massive thanks again for putting up with me for 8 weeks and getting all the way to the final cell! I'm excited to hear all about your career as an LLM Engineer. If you post on LinkedIn about completing the course and tag me, then I'll weigh in to amplify your achievement. <br/><b>You could not have picked a better time to be in this field.</b>
#             </span>
#         </td>
#     </tr>
# </table>
