# %% [markdown]
# # "THE PRICE IS RIGHT" Capstone Project
#
# This week - build a model that predicts how much something costs from a description, based on a scrape of Amazon data
#
# # Order of play
#
# DAY 1: Data Curation
# DAY 2: Data Pre-processing
# DAY 3: Evaluation, Baselines, Traditional ML
# DAY 4: Deep Learning and LLMs
# DAY 5: Fine-tuning a Frontier Model
#
# ## DAY 5: Fine-tuning a Frontier Model
#
# Now we will use OpenAI's API to fine-tune our own private variant of GPT-4.1-nano

# %%
# imports

import os
import re
import json
from dotenv import load_dotenv
from huggingface_hub import login
from openai import OpenAI
from pricer.items  import Item
from pricer.evaluator import evaluate

# %%
# environment

LITE_MODE = False

load_dotenv(override=True)
hf_token = os.environ['HF_TOKEN']
login(hf_token, add_to_git_credential=True)
# Out:
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.

# %%
username = "ed-donner"
dataset = f"{username}/items_lite" if LITE_MODE else f"{username}/items_full"

train, val, test = Item.from_hub(dataset)

print(f"Loaded {len(train):,} training items, {len(val):,} validation items, {len(test):,} test items")
# Out:
# Loaded 800,000 training items, 10,000 validation items, 10,000 test items

# %%
openai = OpenAI()

# %% [markdown]
# # Data size
#
# OpenAI recommends fine-tuning with a small population of 50-100 examples
#
# I'm going to go with 20,000 points.
#
# This cost me $3.42 - you should stick with 100 examples and the cost will be minimal!

# %%
# OpenAI recommends fine-tuning with populations of 50-100 examples
# But as our examples are very small, I'm suggesting we go with 100 examples (and 1 epoch)


fine_tune_train = train[:100]
fine_tune_validation = val[:50]

# %%
len(fine_tune_train)
# Out:
# 100

# %% [markdown]
# # Step 1
#
# Prepare our data for fine-tuning in JSONL (JSON Lines) format and upload to OpenAI

# %%
def messages_for(item):
    message = f"Estimate the price of this product. Respond with the price, no explanation\n\n{item.summary}"
    return [
        {"role": "user", "content": message},
        {"role": "assistant", "content": f"${item.price:.2f}"}
    ]

# %%
messages_for(fine_tune_train[0])
# Out:
# [{'role': 'user',
#   'content': 'Estimate the price of this product. Respond with the price, no explanation\n\nTitle: Schlage F59 & 613 Andover Interior Knob (Deadbolt Included)  \nCategory: Home Hardware  \nBrand: Schlage  \nDescription: A single‑piece oil‑rubbed bronze knob that mounts to a deadbolt for secure, easy interior door use.  \nDetails: Designed for a 4" minimum center‑to‑center door prep, it offers a lifetime mechanical and finish warranty and comes ready for quick installation.'},
#  {'role': 'assistant', 'content': '$64.30'}]

# %%
# Convert the items into a list of json objects - a "jsonl" string
# Each row represents a message in the form:
# {"messages" : [{"role": "system", "content": "You estimate prices...


def make_jsonl(items):
    result = ""
    for item in items:
        messages = messages_for(item)
        messages_str = json.dumps(messages)
        result += '{"messages": ' + messages_str +'}\n'
    return result.strip()

# %%
print(make_jsonl(train[:3]))
# Out:
# {"messages": [{"role": "user", "content": "Estimate the price of this product. Respond with the price, no explanation\n\nTitle: Schlage F59 & 613 Andover Interior Knob (Deadbolt Included)  \nCategory: Home Hardware  \nBrand: Schlage  \nDescription: A single\u2011piece oil\u2011rubbed bronze knob that mounts to a deadbolt for secure, easy interior door use.  \nDetails: Designed for a 4\" minimum center\u2011to\u2011center door prep, it offers a lifetime mechanical and finish warranty and comes ready for quick installation."}, {"role": "assistant", "content": "$64.30"}]}
# {"messages": [{"role": "user", "content": "Estimate the price of this product. Respond with the price, no explanation\n\nTitle: Mini Electric Air Duster Fan  \nCategory: Electronics  \nBrand: Kica  \nDescription: Ultra\u2011compact 86,000\u202fRPM electric air duster with 11\u202fm/s wind speed for precise cleaning and inflation.  \nDetails: Powered by a 9.99\u202fWh motor, adjustable in four speed levels, it uses three lithium\u2011ion batteries and fits easily into pocket-sized applications."}, {"role": "assistant", "content": "$79.00"}]}
# {"messages": [{"role": "user", "content": "Estimate the price of this product. Respond with the price, no explanation\n\nTitle: Bose QuietComfort 35 I Wireless Noise Cancelling Headphones  \nCategory: Electronics  \nBrand: Bose  \nDescription: Premium wireless headphones delivering industry\u2011leading noise cancellation and balanced audio for immersive listening.  \nDetails: Bluetooth and NFC pairing, dual\u2011microphone call clarity, up to 20\u202fhours battery life, and a lightweight, comfortable design."}, {"role": "assistant", "content": "$240.00"}]}

# %%
# Convert the items into jsonl and write them to a file

def write_jsonl(items, filename):
    with open(filename, "w") as f:
        jsonl = make_jsonl(items)
        f.write(jsonl)

# %%
write_jsonl(fine_tune_train, "jsonl/fine_tune_train.jsonl")

# %%
write_jsonl(fine_tune_validation, "jsonl/fine_tune_validation.jsonl")

# %%
with open("jsonl/fine_tune_train.jsonl", "rb") as f:
    train_file = openai.files.create(file=f, purpose="fine-tune")

# %%
train_file
# Out:
# FileObject(id='file-1cakch4M8b5jDFeBiTdixw', bytes=55120, created_at=1786678941, filename='fine_tune_train.jsonl', object='file', purpose='fine-tune', status='processed', expires_at=None, status_details=None)

# %%
with open("jsonl/fine_tune_validation.jsonl", "rb") as f:
    validation_file = openai.files.create(file=f, purpose="fine-tune")

# %%
validation_file
# Out:
# FileObject(id='file-AQYULpdA8RhtnaXie5jmKV', bytes=27637, created_at=1786678945, filename='fine_tune_validation.jsonl', object='file', purpose='fine-tune', status='processed', expires_at=None, status_details=None)

# %% [markdown]
# https://platform.openai.com/storage/files/

# %% [markdown]
# # Step 2
#
# ## And now time to Fine-tune!

# %%
from openai import OpenAI

client = OpenAI()

product_description = """
A stainless-steel countertop blender with a 1,200-watt motor,
64-ounce container, and three-year warranty.
"""

response = client.responses.create(
    model="gpt-5.6-luna",
    input=[
        {
            "role": "developer",
            "content": "Estimate the product's price in USD. Return only the price."
        },
        {
            "role": "user",
            "content": product_description
        }
    ],
)

print(response.output_text)
# Out:
# $129.99

# %%
from openai import OpenAI

client = OpenAI()

response = client.responses.create(
    model="gpt-5.6-luna",
    input=[
        {
            "role": "developer",
            "content": "Estimate the product price from its description."
        },
        {
            "role": "user",
            "content": product_description
        }
    ],
)

print(response.output_text)
# Out:
# Estimated price: **$120–$200 USD**.
#
# A reasonable midpoint estimate is **about $160**, assuming it’s a mid-range consumer blender with a stainless-steel finish and a three-year warranty.

# %%
openai.fine_tuning.jobs.create(
    training_file=train_file.id,
    validation_file=validation_file.id,
    model="gpt-4.1-nano-2025-04-14",
    seed=42,
    hyperparameters={"n_epochs": 1, "batch_size": 1},
    suffix="pricer"
)
# Out:
# ---------------------------------------------------------------------------
# PermissionDeniedError                     Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 openai.fine_tuning.jobs.create(
#       2     training_file=train_file.id,
#       3     validation_file=validation_file.id,
#       4     model="gpt-4.1-nano-2025-04-14",
#       5     seed=42,
#       6     hyperparameters={"n_epochs": 1, "batch_size": 1},
#       7     suffix="pricer"
#       8 )
#
# File ~/Projects/llm_engineering/.venv/lib/python3.12/site-packages/openai/resources/fine_tuning/jobs/jobs.py:158, in Jobs.create(self, model, training_file, hyperparameters, integrations, metadata, method, seed, suffix, validation_file, extra_headers, extra_query, extra_body, timeout)
#      61 def create(
#      62     self,
#      63     *,
#    (...)     78     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#      79 ) -> FineTuningJob:
#      80     """
#      81     Creates a fine-tuning job which begins the process of creating a new model from
#      82     a given dataset.
#    (...)    156       timeout: Override the client-level default timeout for this request, in seconds
#     157     """
# --> 158     return self._post(
#     159         "/fine_tuning/jobs",
#     160         body=maybe_transform(
#     161             {
#     162                 "model": model,
#     163                 "training_file": training_file,
#     164                 "hyperparameters": hyperparameters,
#     165                 "integrations": integrations,
#     166                 "metadata": metadata,
#     167                 "method": method,
#     168                 "seed": seed,
#     169                 "suffix": suffix,
#     170                 "validation_file": validation_file,
#     171             },
#     172             job_create_params.JobCreateParams,
#     173         ),
#     174         options=make_request_options(
#     175             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     176         ),
#     177         cast_to=FineTuningJob,
#     178     )
#
# File ~/Projects/llm_engineering/.venv/lib/python3.12/site-packages/openai/_base_client.py:1259, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1245 def post(
#    1246     self,
#    1247     path: str,
#    (...)   1254     stream_cls: type[_StreamT] | None = None,
#    1255 ) -> ResponseT | _StreamT:
#    1256     opts = FinalRequestOptions.construct(
#    1257         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1258     )
# -> 1259     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/Projects/llm_engineering/.venv/lib/python3.12/site-packages/openai/_base_client.py:1047, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1044             err.response.read()
#    1046         log.debug("Re-raising status error")
# -> 1047         raise self._make_status_error_from_response(err.response) from None
#    1049     break
#    1051 assert response is not None, "could not resolve response (should never happen)"
#
# PermissionDeniedError: Error code: 403 - {'error': {'message': 'OpenAI is winding down the fine-tuning platform and your organization is no longer able to create new fine-tuning training jobs. Learn more https://developers.openai.com/api/docs/deprecations#update-to-openais-self-serve-fine-tuning', 'type': 'invalid_request_error', 'param': None, 'code': 'training_not_available'}}

# %%
openai.fine_tuning.jobs.list(limit=1)
# Out:
# SyncCursorPage[FineTuningJob](data=[], has_more=False, object='list')

# %%
job_id = openai.fine_tuning.jobs.list(limit=1).data[0].id
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 job_id = openai.fine_tuning.jobs.list(limit=1).data[0].id
#
# IndexError: list index out of range

# %%
job_id

# %%
openai.fine_tuning.jobs.retrieve(job_id)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 openai.fine_tuning.jobs.retrieve(job_id)
#
# File ~/Projects/llm_engineering/.venv/lib/python3.12/site-packages/openai/resources/fine_tuning/jobs/jobs.py:206, in Jobs.retrieve(self, fine_tuning_job_id, extra_headers, extra_query, extra_body, timeout)
#     191 """
#     192 Get info about a fine-tuning job.
#     193
#    (...)    203   timeout: Override the client-level default timeout for this request, in seconds
#     204 """
#     205 if not fine_tuning_job_id:
# --> 206     raise ValueError(f"Expected a non-empty value for `fine_tuning_job_id` but received {fine_tuning_job_id!r}")
#     207 return self._get(
#     208     f"/fine_tuning/jobs/{fine_tuning_job_id}",
#     209     options=make_request_options(
#    (...)    212     cast_to=FineTuningJob,
#     213 )
#
# ValueError: Expected a non-empty value for `fine_tuning_job_id` but received None

# %%
openai.fine_tuning.jobs.list_events(fine_tuning_job_id=job_id, limit=10).data
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 openai.fine_tuning.jobs.list_events(fine_tuning_job_id=job_id, limit=10).data
#
# File ~/Projects/llm_engineering/.venv/lib/python3.12/site-packages/openai/resources/fine_tuning/jobs/jobs.py:330, in Jobs.list_events(self, fine_tuning_job_id, after, limit, extra_headers, extra_query, extra_body, timeout)
#     313 """
#     314 Get status updates for a fine-tuning job.
#     315
#    (...)    327   timeout: Override the client-level default timeout for this request, in seconds
#     328 """
#     329 if not fine_tuning_job_id:
# --> 330     raise ValueError(f"Expected a non-empty value for `fine_tuning_job_id` but received {fine_tuning_job_id!r}")
#     331 return self._get_api_list(
#     332     f"/fine_tuning/jobs/{fine_tuning_job_id}/events",
#     333     page=SyncCursorPage[FineTuningJobEvent],
#    (...)    347     model=FineTuningJobEvent,
#     348 )
#
# ValueError: Expected a non-empty value for `fine_tuning_job_id` but received None

# %% [markdown]
# https://platform.openai.com/finetune

# %% [markdown]
# # Step 3
#
# Test our fine tuned model

# %%
fine_tuned_model_name = openai.fine_tuning.jobs.retrieve(job_id).fine_tuned_model
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 fine_tuned_model_name = openai.fine_tuning.jobs.retrieve(job_id).fine_tuned_model
#
# File ~/Projects/llm_engineering/.venv/lib/python3.12/site-packages/openai/resources/fine_tuning/jobs/jobs.py:206, in Jobs.retrieve(self, fine_tuning_job_id, extra_headers, extra_query, extra_body, timeout)
#     191 """
#     192 Get info about a fine-tuning job.
#     193
#    (...)    203   timeout: Override the client-level default timeout for this request, in seconds
#     204 """
#     205 if not fine_tuning_job_id:
# --> 206     raise ValueError(f"Expected a non-empty value for `fine_tuning_job_id` but received {fine_tuning_job_id!r}")
#     207 return self._get(
#     208     f"/fine_tuning/jobs/{fine_tuning_job_id}",
#     209     options=make_request_options(
#    (...)    212     cast_to=FineTuningJob,
#     213 )
#
# ValueError: Expected a non-empty value for `fine_tuning_job_id` but received None

# %%
fine_tuned_model_name
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 fine_tuned_model_name
#
# NameError: name 'fine_tuned_model_name' is not defined

# %%
# The prompt

def test_messages_for(item):
    message = f"Estimate the price of this product. Respond with the price, no explanation\n\n{item.summary}"
    return [
        {"role": "user", "content": message},
    ]

# %%
# Try this out

test_messages_for(test[0])
# Out:
# [{'role': 'user',
#   'content': 'Estimate the price of this product. Respond with the price, no explanation\n\nTitle: Excess V2 Distortion/Modulation Pedal  \nCategory: Music Pedals  \nBrand: Old Blood Noise  \nDescription: A versatile pedal offering distortion and three modulation modes—delay, chorus, and harmonized fifths—with full control over signal routing and expression.  \nDetails: Features include separate gain, tone, and volume controls; time, depth, and volume per modulation; order switching, soft‑touch bypass, and expression jack for dynamic control.'}]

# %%
# The inference function


def gpt_4__1_nano_fine_tuned(item):
    response = openai.chat.completions.create(
        model=fine_tuned_model_name,
        messages=test_messages_for(item),
        max_tokens=7
    )
    return response.choices[0].message.content

# %%
print(test[0].price)
print(gpt_4__1_nano_fine_tuned(test[0]))
# Out:
# 219.0
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[76], line 2
#       1 print(test[0].price)
# ----> 2 print(gpt_4__1_nano_fine_tuned(test[0]))
#
# Cell In[75], line 6, in gpt_4__1_nano_fine_tuned(item)
#       4 def gpt_4__1_nano_fine_tuned(item):
#       5     response = openai.chat.completions.create(
# ----> 6         model=fine_tuned_model_name,
#       7         messages=test_messages_for(item),
#       8         max_tokens=7
#       9     )
#      10     return response.choices[0].message.content
#
# NameError: name 'fine_tuned_model_name' is not defined

# %%
evaluate(gpt_4__1_nano_fine_tuned, test)
# Out:
#   0%|          | 0/200 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[77], line 1
# ----> 1 evaluate(gpt_4__1_nano_fine_tuned, test)
#
# File ~/Projects/llm_engineering/week6/pricer/evaluator.py:218, in evaluate(function, data, size, workers)
#     217 def evaluate(function, data, size=DEFAULT_SIZE, workers=WORKERS):
# --> 218     Tester(function, data, size=size, workers=workers).run()
#
# File ~/Projects/llm_engineering/week6/pricer/evaluator.py:205, in Tester.run(self)
#     203 def run(self):
#     204     with ThreadPoolExecutor(max_workers=self.workers) as ex:
# --> 205         for title, guess, truth, error, color in tqdm(
#     206             ex.map(self.run_datapoint, range(self.size)), total=self.size
#     207         ):
#     208             self.titles.append(title)
#     209             self.guesses.append(guess)
#
# File ~/Projects/llm_engineering/.venv/lib/python3.12/site-packages/tqdm/notebook.py:250, in tqdm_notebook.__iter__(self)
#     248 try:
#     249     it = super().__iter__()
# --> 250     for obj in it:
#     251         # return super(tqdm...) will not catch exception
#     252         yield obj
#     253 # NB: except ... [ as ...] breaks IPython async KeyboardInterrupt
#
# File ~/Projects/llm_engineering/.venv/lib/python3.12/site-packages/tqdm/std.py:1181, in tqdm.__iter__(self)
#    1178 time = self._time
#    1180 try:
# -> 1181     for obj in iterable:
#    1182         yield obj
#    1183         # Update and possibly print the progressbar.
#    1184         # Note: does not call self.update(1) for speed optimisation.
#
# File ~/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/concurrent/futures/_base.py:619, in Executor.map.<locals>.result_iterator()
#     616 while fs:
#     617     # Careful not to keep a reference to the popped future
#     618     if timeout is None:
# --> 619         yield _result_or_cancel(fs.pop())
#     620     else:
#     621         yield _result_or_cancel(fs.pop(), end_time - time.monotonic())
#
# File ~/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/concurrent/futures/_base.py:317, in _result_or_cancel(***failed resolving arguments***)
#     315 try:
#     316     try:
# --> 317         return fut.result(timeout)
#     318     finally:
#     319         fut.cancel()
#
# File ~/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/concurrent/futures/_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File ~/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/concurrent/futures/thread.py:59, in _WorkItem.run(self)
#      56     return
#      58 try:
# ---> 59     result = self.fn(*self.args, **self.kwargs)
#      60 except BaseException as exc:
#      61     self.future.set_exception(exc)
#
# File ~/Projects/llm_engineering/week6/pricer/evaluator.py:57, in Tester.run_datapoint(self, i)
#      55 def run_datapoint(self, i):
#      56     datapoint = self.data[i]
# ---> 57     value = self.predictor(datapoint)
#      58     guess = self.post_process(value)
#      59     truth = datapoint.price
#
# Cell In[75], line 6, in gpt_4__1_nano_fine_tuned(item)
#       4 def gpt_4__1_nano_fine_tuned(item):
#       5     response = openai.chat.completions.create(
# ----> 6         model=fine_tuned_model_name,
#       7         messages=test_messages_for(item),
#       8         max_tokens=7
#       9     )
#      10     return response.choices[0].message.content
#
# NameError: name 'fine_tuned_model_name' is not defined

# %%
# 96.58 - mini 200
# 79.29 - mini 2000
# 82.26 - nano 2000
# 67.75 - nano 20,000

# %%
import os; print(os.getcwd())
# Out:
# /Users/tejavu/Projects/llm_engineering/week6

# %%
import os
import re
import json
from dotenv import load_dotenv
from huggingface_hub import login
from openai import OpenAI
from pricer.items  import Item
from pricer.evaluator import evaluate

# %%
LITE_MODE = False

load_dotenv(override=True)
hf_token = os.environ['HF_TOKEN']
login(hf_token, add_to_git_credential=True)
# Out:
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.

# %%
username = "ed-donner"
dataset = f"{username}/items_lite" if LITE_MODE else f"{username}/items_full"

train, val, test = Item.from_hub(dataset)

print(f"Loaded {len(train):,} training items, {len(val):,} validation items, {len(test):,} test items")
# Out:
# Loaded 800,000 training items, 10,000 validation items, 10,000 test items

# %%
openai = OpenAI()

# %%
fine_tune_train = train[:100]
fine_tune_validation = val[:50]
len(fine_tune_train)
# Out:
# 100

# %%
def messages_for(item):
    message = f"Estimate the price of this product. Respond with the price, no explanation\n\n{item.summary}"
    return [
        {"role": "user", "content": message},
        {"role": "assistant", "content": f"${item.price:.2f}"}
    ]

messages_for(fine_tune_train[0])
# Out:
# [{'role': 'user',
#   'content': 'Estimate the price of this product. Respond with the price, no explanation\n\nTitle: Schlage F59 & 613 Andover Interior Knob (Deadbolt Included)  \nCategory: Home Hardware  \nBrand: Schlage  \nDescription: A single‑piece oil‑rubbed bronze knob that mounts to a deadbolt for secure, easy interior door use.  \nDetails: Designed for a 4" minimum center‑to‑center door prep, it offers a lifetime mechanical and finish warranty and comes ready for quick installation.'},
#  {'role': 'assistant', 'content': '$64.30'}]

# %%
def make_jsonl(items):
    result = ""
    for item in items:
        messages = messages_for(item)
        messages_str = json.dumps(messages)
        result += '{"messages": ' + messages_str +'}\n'
    return result.strip()

print(make_jsonl(train[:3]))
# Out:
# {"messages": [{"role": "user", "content": "Estimate the price of this product. Respond with the price, no explanation\n\nTitle: Schlage F59 & 613 Andover Interior Knob (Deadbolt Included)  \nCategory: Home Hardware  \nBrand: Schlage  \nDescription: A single\u2011piece oil\u2011rubbed bronze knob that mounts to a deadbolt for secure, easy interior door use.  \nDetails: Designed for a 4\" minimum center\u2011to\u2011center door prep, it offers a lifetime mechanical and finish warranty and comes ready for quick installation."}, {"role": "assistant", "content": "$64.30"}]}
# {"messages": [{"role": "user", "content": "Estimate the price of this product. Respond with the price, no explanation\n\nTitle: Mini Electric Air Duster Fan  \nCategory: Electronics  \nBrand: Kica  \nDescription: Ultra\u2011compact 86,000\u202fRPM electric air duster with 11\u202fm/s wind speed for precise cleaning and inflation.  \nDetails: Powered by a 9.99\u202fWh motor, adjustable in four speed levels, it uses three lithium\u2011ion batteries and fits easily into pocket-sized applications."}, {"role": "assistant", "content": "$79.00"}]}
# {"messages": [{"role": "user", "content": "Estimate the price of this product. Respond with the price, no explanation\n\nTitle: Bose QuietComfort 35 I Wireless Noise Cancelling Headphones  \nCategory: Electronics  \nBrand: Bose  \nDescription: Premium wireless headphones delivering industry\u2011leading noise cancellation and balanced audio for immersive listening.  \nDetails: Bluetooth and NFC pairing, dual\u2011microphone call clarity, up to 20\u202fhours battery life, and a lightweight, comfortable design."}, {"role": "assistant", "content": "$240.00"}]}

# %%
def write_jsonl(items, filename):
    with open(filename, "w") as f:
        jsonl = make_jsonl(items)
        f.write(jsonl)

write_jsonl(fine_tune_train, "jsonl/fine_tune_train.jsonl")
write_jsonl(fine_tune_validation, "jsonl/fine_tune_validation.jsonl")

# %%
with open("jsonl/fine_tune_train.jsonl", "rb") as f:
    train_file = openai.files.create(file=f, purpose="fine-tune")
train_file
# Out:
# FileObject(id='file-2PraWKjtR6zfDFen4MRtEK', bytes=55120, created_at=1786678642, filename='fine_tune_train.jsonl', object='file', purpose='fine-tune', status='processed', expires_at=None, status_details=None)

# %%
with open("jsonl/fine_tune_validation.jsonl", "rb") as f:
    validation_file = openai.files.create(file=f, purpose="fine-tune")
validation_file
# Out:
# FileObject(id='file-4sQdeFprKTLxrx5JumWF8K', bytes=27637, created_at=1786678648, filename='fine_tune_validation.jsonl', object='file', purpose='fine-tune', status='processed', expires_at=None, status_details=None)

# %%
job = openai.fine_tuning.jobs.create(
    training_file=train_file.id,
    validation_file=validation_file.id,
    model="gpt-4.1-nano-2025-04-14",
    seed=42,
    hyperparameters={"n_epochs": 1, "batch_size": 1},
    suffix="pricer"
)
job
# Out:
# ---------------------------------------------------------------------------
# PermissionDeniedError                     Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 job = openai.fine_tuning.jobs.create(
#       2     training_file=train_file.id,
#       3     validation_file=validation_file.id,
#       4     model="gpt-4.1-nano-2025-04-14",
#       5     seed=42,
#       6     hyperparameters={"n_epochs": 1, "batch_size": 1},
#       7     suffix="pricer"
#       8 )
#       9 job
#
# File ~/Projects/llm_engineering/.venv/lib/python3.12/site-packages/openai/resources/fine_tuning/jobs/jobs.py:158, in Jobs.create(self, model, training_file, hyperparameters, integrations, metadata, method, seed, suffix, validation_file, extra_headers, extra_query, extra_body, timeout)
#      61 def create(
#      62     self,
#      63     *,
#    (...)     78     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#      79 ) -> FineTuningJob:
#      80     """
#      81     Creates a fine-tuning job which begins the process of creating a new model from
#      82     a given dataset.
#    (...)    156       timeout: Override the client-level default timeout for this request, in seconds
#     157     """
# --> 158     return self._post(
#     159         "/fine_tuning/jobs",
#     160         body=maybe_transform(
#     161             {
#     162                 "model": model,
#     163                 "training_file": training_file,
#     164                 "hyperparameters": hyperparameters,
#     165                 "integrations": integrations,
#     166                 "metadata": metadata,
#     167                 "method": method,
#     168                 "seed": seed,
#     169                 "suffix": suffix,
#     170                 "validation_file": validation_file,
#     171             },
#     172             job_create_params.JobCreateParams,
#     173         ),
#     174         options=make_request_options(
#     175             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     176         ),
#     177         cast_to=FineTuningJob,
#     178     )
#
# File ~/Projects/llm_engineering/.venv/lib/python3.12/site-packages/openai/_base_client.py:1259, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1245 def post(
#    1246     self,
#    1247     path: str,
#    (...)   1254     stream_cls: type[_StreamT] | None = None,
#    1255 ) -> ResponseT | _StreamT:
#    1256     opts = FinalRequestOptions.construct(
#    1257         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1258     )
# -> 1259     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/Projects/llm_engineering/.venv/lib/python3.12/site-packages/openai/_base_client.py:1047, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1044             err.response.read()
#    1046         log.debug("Re-raising status error")
# -> 1047         raise self._make_status_error_from_response(err.response) from None
#    1049     break
#    1051 assert response is not None, "could not resolve response (should never happen)"
#
# PermissionDeniedError: Error code: 403 - {'error': {'message': 'OpenAI is winding down the fine-tuning platform and your organization is no longer able to create new fine-tuning training jobs. Learn more https://developers.openai.com/api/docs/deprecations#update-to-openais-self-serve-fine-tuning', 'type': 'invalid_request_error', 'param': None, 'code': 'training_not_available'}}
